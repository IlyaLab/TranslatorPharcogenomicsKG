# %%
## Load necessary packages
import os
import pandas as pd
import glob
import numpy as np
import networkx as nx
# import matplotlib.pyplot as plt

## load the needed tqdm package
from tqdm import tqdm

# Enable tqdm for pandas apply
tqdm.pandas()

# %%
## Notice!! Please change the file path of following codes into your own
FDA_approved_drugs_list_files_path = '/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/FDA_approved_drug_list/EOBZIP_2026_01/'

## Note! define download path in the very end of the notebook!!

# %%
## Check all node files being read
## Read all BigGIM node csv file in group 1

for f in os.listdir(FDA_approved_drugs_list_files_path):
    if f.endswith('.txt'):
        print(f)
# Out:
# exclusivity.txt
# products.txt
# patent.txt

# %%
FDA_products_df = pd.read_csv(FDA_approved_drugs_list_files_path + "products.txt", sep="~")
FDA_products_df.to_csv(FDA_approved_drugs_list_files_path + "fda_approved_drugs.csv", index=False)

# %%
## Read each individual csv files
source_df = pd.read_csv(FDA_approved_drugs_list_files_path + 'fda_approved_drugs.csv')

## check the length
print("current row number is: ", len(source_df))

source_df.head(10)
# Out:
# current row number is:  47780
#                                   Ingredient               DF;Route  \
# 0                                 BUDESONIDE   AEROSOL, FOAM;RECTAL
# 1                                 BUDESONIDE   AEROSOL, FOAM;RECTAL
# 2                  MINOCYCLINE HYDROCHLORIDE  AEROSOL, FOAM;TOPICAL
# 3                               AZELAIC ACID  AEROSOL, FOAM;TOPICAL
# 4                     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL
# 5                     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL
# 6                     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL
# 7                     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL
# 8                     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL
# 9  BETAMETHASONE DIPROPIONATE; CALCIPOTRIENE  AEROSOL, FOAM;TOPICAL
#
#                                      Trade_Name             Applicant  \
# 0                                    BUDESONIDE        PADAGIS ISRAEL
# ...
