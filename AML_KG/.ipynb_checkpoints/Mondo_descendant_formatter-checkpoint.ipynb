# %%
## Define the version number
version_number = "05_12_2025"

# %%
from owlready2 import *

onto = get_ontology("http://purl.obolibrary.org/obo/mondo.owl").load()
term = onto.search_one(iri="http://purl.obolibrary.org/obo/{}".format('MONDO_0018874'))
descendants = term.descendants()

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.2.5

# %%
print(descendants)
# Out:
# {obo.MONDO_0100391, obo.MONDO_0019457, obo.MONDO_0100410, obo.MONDO_0019456, obo.MONDO_0015164, obo.MONDO_0100396, obo.MONDO_0100416, obo.MONDO_0005223, obo.MONDO_0100382, obo.MONDO_0006237, obo.MONDO_0100401, obo.MONDO_0850450, obo.MONDO_0100421, obo.MONDO_0017858, obo.MONDO_0100377, obo.MONDO_0100387, obo.MONDO_0850271, obo.MONDO_0015667, obo.MONDO_0100406, obo.MONDO_0018434, obo.MONDO_0100373, obo.MONDO_0850269, obo.MONDO_0100392, obo.MONDO_0020316, obo.MONDO_0015165, obo.MONDO_0100397, obo.MONDO_0100417, obo.MONDO_0005224, obo.MONDO_0020320, obo.MONDO_0100383, obo.MONDO_0859598, obo.MONDO_0100402, obo.MONDO_0850451, obo.MONDO_0100412, obo.MONDO_0100422, obo.MONDO_0018872, obo.MONDO_0100378, obo.MONDO_0100388, obo.MONDO_0971091, obo.MONDO_0019460, obo.MONDO_0100407, obo.MONDO_0018435, obo.MONDO_0850492, obo.MONDO_0100374, obo.MONDO_0100393, obo.MONDO_0020317, obo.MONDO_0015608, obo.MONDO_0100398, obo.MONDO_0017894, obo.MONDO_0100418, obo.MONDO_0011118, obo.MONDO_0100384, obo.MONDO_0018004, obo.MONDO_0100403, obo.MONDO_0850452, obo.MONDO_0100413, obo.MONDO_0100423, obo.MONDO_0018871, obo.MONDO_0100379, obo.MONDO_0100389, obo.MONDO_0012883, obo.MONDO_0100408, obo.MONDO_0018436, obo.MONDO_0850495, obo.MONDO_0100375, obo.MONDO_0100394, obo.MONDO_0017893, obo.MONDO_0035112, obo.MONDO_0004051, obo.MONDO_0035639, obo.MONDO_0007896, obo.MONDO_0100399, obo.MONDO_0020322, obo.MONDO_0018256, obo.MONDO_0100419, obo.MONDO_0006861, obo.MONDO_0020321, obo.MONDO_0100385, obo.MONDO_0020526, obo.MONDO_0100404, obo.MONDO_0100414, obo.MONDO_0018874, obo.MONDO_0100424, obo.MONDO_0019455, obo.MONDO_0100380, obo.MONDO_0100390, obo.MONDO_0015166, obo.MONDO_0100409, obo.MONDO_0018437, obo.MONDO_0004996, obo.MONDO_0000875, obo.MONDO_0100376, obo.MONDO_0100395, obo.MONDO_0044923, obo.MONDO_0100415, obo.MONDO_0004644, obo.MONDO_0100381, obo.MONDO_0035642, obo.MONDO_0100400, obo.MONDO_0850449, obo.MONDO_0018433, obo.MONDO_0100420, obo.MONDO_0020743, obo.MONDO_0100386, obo.MONDO_0850267, obo.MONDO_0100405, obo.MONDO_0100425, obo.MONDO_0019458}

# %%
print(len(descendants))
# Out:
# 108

# %%
from owlready2 import get_ontology
import pandas as pd

# Load the MONDO ontology (can take time the first time it's downloaded)
mondo_url = "http://purl.obolibrary.org/obo/mondo.owl"
onto = get_ontology(mondo_url).load()

# Replace with your MONDO ID of interest
input_mondo_id = "MONDO_0018874"  # e.g., acute myeloid leukemia

# Search for the class
input_class = onto.search_one(iri="*"+input_mondo_id)

if input_class:
    print(f"Input MONDO term: {input_class.name} - {input_class.label}")

    # Recursive function to get all descendants
    def get_descendants(cls):
        all_desc = set()
        for subclass in cls.subclasses():
            all_desc.add(subclass)
            all_desc.update(get_descendants(subclass))
        return all_desc

    descendants = get_descendants(input_class)

    # Store in DataFrame
    data = []
    for desc in descendants:
        mondo_id = desc.name
        label = desc.label[0] if desc.label else "No label"
        data.append({"object_identifier": mondo_id, "object_name": label})

    df = pd.DataFrame(data).sort_values(by="object_identifier")

    print(f"\nTotal descendants found: {len(df)}\n")
    print(df.head())  # Show a preview

else:
    print("MONDO class not found.")
# Out:
# Input MONDO term: MONDO_0018874 - ['acute myeloid leukemia']
#
# Total descendants found: 107
#
#    object_identifier                                        object_name
# 89     MONDO_0000875                     adult acute monocytic leukemia
# 68     MONDO_0004051                 aleukemic monocytic leukemia cutis
# 94     MONDO_0004644                        subacute monocytic leukemia
# 87     MONDO_0004996                   childhood acute myeloid leukemia
# 7      MONDO_0005223  acute myeloid leukemia with minimal differenti...

# %%
## replace the _ to : in the object_identifier results
df['object_identifier'] = df['object_identifier'].str.replace('_', ':', regex=False)
df['object_category'] = 'biolink:Disease'

## add constant columns: subject_identifier, subject_name, subject_category, predicate
df['subject_identifier'] = input_mondo_id.replace("_", ":")
df['subject_name'] = 'acute myeloid leukemia'
df['subject_category'] = 'biolink:Disease'
df['predicate'] = 'biolink:subclass_of'

df['knowledge_level'] = 'knowledge_assertion'
df['knowledge_source'] = 'Mondo Disease Ontology'
df['disease_context_qualifier'] = input_mondo_id.replace("_", ":")

print(df.head(20))
# Out:
#    object_identifier                                        object_name  \
# 89     MONDO:0000875                     adult acute monocytic leukemia
# 68     MONDO:0004051                 aleukemic monocytic leukemia cutis
# 94     MONDO:0004644                        subacute monocytic leukemia
# 87     MONDO:0004996                   childhood acute myeloid leukemia
# 7      MONDO:0005223  acute myeloid leukemia with minimal differenti...
# 27     MONDO:0005224     acute myeloblastic leukemia without maturation
# 8      MONDO:0006237                               granulocytic sarcoma
# 75     MONDO:0006861                                    myeloid sarcoma
# 70     MONDO:0007896                           acute monocytic leukemia
# 50     MONDO:0011118                    bilineal acute myeloid leukemia
# 60     MONDO:0012883                       acute promyelocytic leukemia
# 4      MONDO:0015164  acute myeloid leukemia and myelodysplastic syn...
# 24     MONDO:0015165  acute myeloid leukemia and myelodysplastic syn...
# 85     MONDO:0015166  acute myeloid leukemia with t(8;21)(q22;q22) t...
# 46     MONDO:0015608  acute myeloid leukemia and myelodysplastic syn...
# 17     MONDO:0015667       acute myeloid leukemia by FAB classification
# 13     MONDO:0017858                           acute erythroid leukemia
# 66     MONDO:0017893                   inherited acute myeloid leukemia
# 48     MONDO:0017894  acute myeloid leukemia with CEBPA somatic muta...
# 51     MONDO:0018004  acute megakaryoblastic leukemia without down s...
#
#     object_category subject_identifier            subject_name  \
# 89  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 68  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 94  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 87  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 7   biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 27  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 8   biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 75  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 70  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 50  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 60  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 4   biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 24  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 85  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 46  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 17  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 13  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 66  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 48  biolink:Disease      MONDO:0018874  acute myeloid leukemia
# 51  biolink:Disease      MONDO:0018874  acute myeloid leukemia
#
#    subject_category            predicate      knowledge_level  \
# 89  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 68  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 94  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 87  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 7   biolink:Disease  biolink:subclass_of  knowledge_assertion
# 27  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 8   biolink:Disease  biolink:subclass_of  knowledge_assertion
# 75  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 70  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 50  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 60  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 4   biolink:Disease  biolink:subclass_of  knowledge_assertion
# 24  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 85  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 46  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 17  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 13  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 66  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 48  biolink:Disease  biolink:subclass_of  knowledge_assertion
# 51  biolink:Disease  biolink:subclass_of  knowledge_assertion
#
#           knowledge_source disease_context_qualifier
# 89  Mondo Disease Ontology             MONDO:0018874
# 68  Mondo Disease Ontology             MONDO:0018874
# 94  Mondo Disease Ontology             MONDO:0018874
# 87  Mondo Disease Ontology             MONDO:0018874
# 7   Mondo Disease Ontology             MONDO:0018874
# 27  Mondo Disease Ontology             MONDO:0018874
# 8   Mondo Disease Ontology             MONDO:0018874
# 75  Mondo Disease Ontology             MONDO:0018874
# 70  Mondo Disease Ontology             MONDO:0018874
# 50  Mondo Disease Ontology             MONDO:0018874
# 60  Mondo Disease Ontology             MONDO:0018874
# 4   Mondo Disease Ontology             MONDO:0018874
# 24  Mondo Disease Ontology             MONDO:0018874
# 85  Mondo Disease Ontology             MONDO:0018874
# 46  Mondo Disease Ontology             MONDO:0018874
# 17  Mondo Disease Ontology             MONDO:0018874
# 13  Mondo Disease Ontology             MONDO:0018874
# 66  Mondo Disease Ontology             MONDO:0018874
# 48  Mondo Disease Ontology             MONDO:0018874
# 51  Mondo Disease Ontology             MONDO:0018874

# %%
## save the biolink compliant dataframe into a csv file

## Define the output path for node & edge files after formatting
download_path = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/AML_KG_deployment/biolink_compliant/AML.MONDO_descendants.biolink.compliant.{version_number}.tsv'

df.to_csv(download_path, index=False, sep='\t')
