# %%
## Load necessary packages
import os
import pandas as pd
import glob
import numpy as np
import networkx as nx
# import matplotlib.pyplot as plt

## load the needed tqdm package
from tqdm import tqdm

# Enable tqdm for pandas apply
tqdm.pandas()

## Define the version number
## past versions:
# version_number = "08_18_2025"
# deployment_date = "2025-08-18"

## current version number
version_number = "08_30_2026"

# %%
## Load files and concatenate them into one merge tsv file

# %%
## Notice!! Please change the file path of following codes into your own
raw_files_path = '/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/'

## Check all node files being read
## Read all BigGIM node csv file in group 1

for f in os.listdir(raw_files_path):
    if f.endswith('.tsv'):
        print(f)
# Out:
# GtoPdB_approved_drug_detailed_interactions_parsed_node_01_06_2026.tsv
# GtoPdB_approved_drug_detailed_interactions_parsed_edge_01_06_2026.tsv
# FDA_Pharmacogenomic_biomarkers_parsed_edge_09_04_2025.tsv
# FDA_Pharmacogenomic_biomarkers_parsed_node_09_04_2025.tsv
# Pharmacogenomics_KG_parsed_node_08_18_2025.tsv
# SINGNOR_parsed_node_08_18_2025.tsv
# SINGNOR_parsed_edge_08_18_2025.tsv
# Pharmacogenomics_KG_parsed_edge_08_18_2025.tsv
# PrimeKG_parsed_edge_01_06_2026.tsv
# PrimeKG_parsed_node_01_06_2026.tsv
# CIViC_parsed_edge_08_10_2026.tsv
# CIViC_parsed_node_08_10_2026.tsv
# Pharmacogenetic_Associations_table_parsed_node_08_10_2025.tsv
# Pharmacogenetic_Associations_table_parsed_edge_08_10_2025.tsv
# PrimeKG_parsed_edge_08_10_2026.tsv
# Pharmacogenetic_Associations_table_parsed_node_08_10_2026.tsv
# PrimeKG_parsed_node_08_10_2026.tsv
# Pharmacogenetic_Associations_table_parsed_edge_08_10_2026.tsv
# PharmGKB_parsed_edge_09_04_2025.tsv
# PharmGKB_parsed_node_09_04_2025.tsv
# ...

# %% [markdown]
# - Phase 1 deployment contains:
# - Date: 2025-09-04
#     - FDA Pharmacogenomic Biomarker
#     - PharmGKB
#     - SIGNOR
# - Phase 2 deployment contains:
# - Date: 2026-01-06
#     - GtoPdB
# - Phase 3 deployment contains:
# - Date: 2026-08-10
#     - PrimeKG (updated)
#     - FDA pharmacogenetic associations table
#     - CPIC
#     - CIVIC

# %% [markdown]
# ### Read the current version of FDA Pharmacogenomic Biomarker parsed files

# %%
## define phase one version number
version_number = "09_04_2025"

# %%
## Define the output path for node & edge files after formatting
FDA_Pharmacogenomic_biomarkers_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/FDA_Pharmacogenomic_biomarkers_parsed_node_{version_number}.tsv'
FDA_Pharmacogenomic_biomarkers_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/FDA_Pharmacogenomic_biomarkers_parsed_edge_{version_number}.tsv'


## Read each individual csv files
FDA_Pharmacogenomic_biomarkers_node_df = pd.read_csv(FDA_Pharmacogenomic_biomarkers_path_node_file, sep='\t')
FDA_Pharmacogenomic_biomarkers_edge_df = pd.read_csv(FDA_Pharmacogenomic_biomarkers_path_edge_file, sep='\t')

# %%
FDA_Pharmacogenomic_biomarkers_node_df.head(2)
# Out:
#               id          name      category
# 0  RXCUI:2563966   Odevixibat   biolink:Drug
# 1  RXCUI:2571074  Maralixibat   biolink:Drug

# %%
FDA_Pharmacogenomic_biomarkers_edge_df.head(2)
# Out:
#          subject  subject_name subject_category         object object_name  \
# 0  RXCUI:2563966   Odevixibat      biolink:Drug  NCBIGene:8647      ABCB11
# 1  RXCUI:2571074  Maralixibat      biolink:Drug  NCBIGene:8647      ABCB11
#
#   object_category              predicate  \
# 0    biolink:Gene  biolink:has_biomarker
# 1    biolink:Gene  biolink:has_biomarker
#
#                         knowledge_source      knowledge_level  \
# 0  FDA pharmacogenomics biomarkers table  knowledge_assertion
# 1  FDA pharmacogenomics biomarkers table  knowledge_assertion
#
#   context_qualifier         agent_type deploy_date  \
# 0  Gastroenterology  text_mining_agent  2025-09-04
# 1  Gastroenterology  text_mining_agent  2025-09-04
#
#                                      id
# 0  4e1f7def-7e8d-5204-9826-56887ff5ecb5
# 1  d5f51f86-e8a1-5481-8105-cdd2d9efc023

# %% [markdown]
# ### Read the current version of PharmGKB parsed files

# %%
## Define the output path for node & edge files after formatting
PharmGKB_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/PharmGKB_parsed_node_{version_number}.tsv'
PharmGKB_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/PharmGKB_parsed_edge_{version_number}.tsv'


## Read each individual csv files
PharmGKB_node_df = pd.read_csv(PharmGKB_path_node_file, sep='\t')
PharmGKB_edge_df = pd.read_csv(PharmGKB_path_edge_file, sep='\t')

# %%
PharmGKB_node_df.head(2)
# Out:
#                 id    name      category
# 0  NCBIGene:162282  ANKFN1  biolink:Gene
# 1    NCBIGene:1728    NQO1  biolink:Gene

# %%
PharmGKB_edge_df.head(2)
# Out:
#            subject subject_name subject_category                 object  \
# 0  NCBIGene:162282       ANKFN1     biolink:Gene        MeSH:D000075222
# 1  NCBIGene:162282       ANKFN1     biolink:Gene  PUBCHEM.COMPOUND:3639
#
#               object_name         object_category                predicate  \
# 0  Essential hypertension         biolink:Disease  biolink:associated_with
# 1     hydrochlorothiazide  biolink:ChemicalEntity  biolink:associated_with
#
#    subject_direction_qualifier  object_direction_qualifier  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#    object_aspect_qualifier knowledge_source publications      knowledge_level  \
# 0                      NaN         PharmGKB     25695618  knowledge_assertion
# 1                      NaN         PharmGKB     25695618  knowledge_assertion
#
#    context_qualifier       agent_type deploy_date  \
# ...

# %% [markdown]
# ### Read the current version of SIGNOR parsed files

# %%
## Define the output path for node & edge files after formatting
SIGNOR_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/SINGNOR_parsed_node_{version_number}.tsv'
SIGNOR_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/SINGNOR_parsed_edge_{version_number}.tsv'


## Read each individual csv files
signor_node_df = pd.read_csv(SIGNOR_path_node_file, sep='\t')
signor_edge_df = pd.read_csv(SIGNOR_path_edge_file, sep='\t')

# %%
signor_node_df.head(2)
# Out:
#               id     name      category
# 0  NCBIGene:1457  CSNK2A1  biolink:Gene
# 1  NCBIGene:2932    GSK3B  biolink:Gene

# %%
signor_edge_df.head(2)
# Out:
#          subject subject_name subject_category          object object_name  \
# 0  NCBIGene:1457      CSNK2A1     biolink:Gene  NCBIGene:11036     GTF2A1L
# 1  NCBIGene:2932        GSK3B     biolink:Gene   NCBIGene:6688        SPI1
#
#   object_category          predicate  subject_direction_qualifier  \
# 0    biolink:Gene  biolink:regulates                          NaN
# 1    biolink:Gene  biolink:regulates                          NaN
#
#   object_direction_qualifier object_aspect_qualifier provided_by  \
# 0                upregulated   activity or abundance      SIGNOR
# 1              downregulated   activity or abundance      SIGNOR
#
#   knowledge_source                 publications      knowledge_level  \
# 0    SIGNOR-250870  PMID:36243968|PMID:12107178  knowledge_assertion
# 1    SIGNOR-277542  PMID:36243968|PMID:33188146  knowledge_assertion
#
#   context_qualifier       agent_type deploy_date  \
# 0               NaN  automated_agent  2025-09-04
# ...

# %% [markdown]
# ### Read the current version of PrimeKG parsed files

# %%
version_number = "08_10_2026"

## Define the output path for node & edge files after formatting
PrimeKG_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/PrimeKG_parsed_node_{version_number}.tsv'
PrimeKG_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/PrimeKG_parsed_edge_{version_number}.tsv'

## download both node and edge files
## Download the result df
PrimeKG_node_df = pd.read_csv(PrimeKG_path_node_file, sep ='\t')
PrimeKG_edge_df = pd.read_csv(PrimeKG_path_edge_file, sep ='\t')

# %%
PrimeKG_node_df.head(2)
# Out:
#               id    name      category
# 0  NCBIGene:9796  PHYHIP  biolink:Gene
# 1  NCBIGene:7918  GPANK1  biolink:Gene

# %%
PrimeKG_edge_df.head(2)
# Out:
#          subject subject_name subject_category          object object_name  \
# 0  NCBIGene:9796       PHYHIP     biolink:Gene  NCBIGene:56992       KIF15
# 1  NCBIGene:7918       GPANK1     biolink:Gene   NCBIGene:9240       PNMA1
#
#   object_category                        predicate  \
# 0    biolink:Gene  biolink:physical_interacts_with
# 1    biolink:Gene  biolink:physical_interacts_with
#
#    subject_direction_qualifier  object_direction_qualifier  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#    object_aspect_qualifier provided_by knowledge_source  publications  \
# 0                      NaN     PrimeKG          PrimeKG           NaN
# 1                      NaN     PrimeKG          PrimeKG           NaN
#
#        knowledge_level  context_qualifier       agent_type deploy_date  \
# 0  knowledge_assertion                NaN  automated_agent  2026-08-10
# ...

# %% [markdown]
# ## Merge phase 2 new sources

# %%
### Read the current version of GtoPdB parsed files

# %%
version_number = "01_06_2026"

## Define the output path for node & edge files after formatting
GtoPdB_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/GtoPdB_approved_drug_detailed_interactions_parsed_node_{version_number}.tsv'
GtoPdB_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/GtoPdB_approved_drug_detailed_interactions_parsed_edge_{version_number}.tsv'

## download both node and edge files
## Download the result df
GtoPdB_node_df = pd.read_csv(GtoPdB_path_node_file, sep ='\t')
GtoPdB_edge_df = pd.read_csv(GtoPdB_path_edge_file, sep ='\t')

# %% [markdown]
# ## Merge phase 3 new sources

# %%
## define the version number
version_number = "08_10_2026"

# %%
## Define the output path for node & edge files after formatting
CIViC_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/CIViC_parsed_node_{version_number}.tsv'
CIViC_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/CIViC_parsed_edge_{version_number}.tsv'

## download both node and edge files
## Download the result df
CIViC_node_df = pd.read_csv(CIViC_path_node_file, sep ='\t')
CIViC_edge_df = pd.read_csv(CIViC_path_edge_file, sep ='\t')

# %%
## Define the output path for node & edge files after formatting
CPIC_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/CPIC_parsed_node_{version_number}.tsv'
CPIC_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/CPIC_parsed_edge_{version_number}.tsv'

## download both node and edge files
## Download the result df
CPIC_node_df = pd.read_csv(CPIC_path_node_file, sep ='\t')
CPIC_edge_df = pd.read_csv(CPIC_path_edge_file, sep ='\t')

# %%
## Define the output path for node & edge files after formatting
Pharmacogenetic_Associations_table_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenetic_Associations_table_parsed_node_{version_number}.tsv'
Pharmacogenetic_Associations_table_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenetic_Associations_table_parsed_edge_{version_number}.tsv'

## download both node and edge files
## Download the result df
Pharmacogenetic_Associations_table_node_df = pd.read_csv(Pharmacogenetic_Associations_table_path_node_file, sep ='\t')
Pharmacogenetic_Associations_table_edge_df = pd.read_csv(Pharmacogenetic_Associations_table_path_edge_file, sep ='\t')

# %% [markdown]
# ## Now starts to merge those individual parsed files
# * current list of parsed files
# * PharmGKB
# * SIGNOR
# * FDA Pharmacogenomics biomarker

# %%
## concatenate signor and cellmarker dfs
list_of_input_node_files = [FDA_Pharmacogenomic_biomarkers_node_df, PharmGKB_node_df, signor_node_df, PrimeKG_node_df, GtoPdB_node_df, CIViC_node_df, CPIC_node_df, Pharmacogenetic_Associations_table_node_df]

list_of_input_edge_files = [FDA_Pharmacogenomic_biomarkers_edge_df, PharmGKB_edge_df, signor_edge_df, PrimeKG_edge_df, GtoPdB_edge_df, CIViC_edge_df, CPIC_edge_df, Pharmacogenetic_Associations_table_edge_df]

PharmacogenomicsKG_node_df = pd.concat(list_of_input_node_files).drop_duplicates()
PharmacogenomicsKG_edge_df = pd.concat(list_of_input_edge_files).drop_duplicates()

# %%
print(len(PharmacogenomicsKG_node_df))
print(len(PharmacogenomicsKG_edge_df))
# Out:
# 66399
# 1017010

# %%
## check if nan value in the object column
PharmacogenomicsKG_edge_filter_df = PharmacogenomicsKG_edge_df.dropna(subset=['object'])

print(len(PharmacogenomicsKG_edge_filter_df))
# Out:
# 1017006

# %%
## check if nan value in the object column
PharmacogenomicsKG_edge_filter_df = PharmacogenomicsKG_edge_filter_df.dropna(subset=['subject'])

print(len(PharmacogenomicsKG_edge_filter_df))
# Out:
# 1017006

# %%
PharmacogenomicsKG_edge_filter_df.head(3)
# Out:
#          subject  subject_name subject_category         object object_name  \
# 0  RXCUI:2563966   Odevixibat      biolink:Drug  NCBIGene:8647      ABCB11
# 1  RXCUI:2571074  Maralixibat      biolink:Drug  NCBIGene:8647      ABCB11
# 2  RXCUI:2571074  Maralixibat      biolink:Drug  NCBIGene:5244       ABCB4
#
#   object_category              predicate  \
# 0    biolink:Gene  biolink:has_biomarker
# 1    biolink:Gene  biolink:has_biomarker
# 2    biolink:Gene  biolink:has_biomarker
#
#                         knowledge_source      knowledge_level  \
# 0  FDA pharmacogenomics biomarkers table  knowledge_assertion
# 1  FDA pharmacogenomics biomarkers table  knowledge_assertion
# 2  FDA pharmacogenomics biomarkers table  knowledge_assertion
#
#   context_qualifier         agent_type deploy_date  \
# 0  Gastroenterology  text_mining_agent  2025-09-04
# 1  Gastroenterology  text_mining_agent  2025-09-04
# 2  Gastroenterology  text_mining_agent  2025-09-04
#
# ...

# %% [markdown]
# ## Download all merged KG
# * need to change to the name of concatenate dataframes

# %%
## Define the output path for node & edge files after formatting
download_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenomics_KG_parsed_node_{version_number}.tsv'
download_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenomics_KG_parsed_edge_{version_number}.tsv'

print(download_path_edge_file)

## download both node and edge files
## Download the result df
## disable download for testing
PharmacogenomicsKG_node_df.to_csv(download_path_node_file, sep ='\t', index=False)
PharmacogenomicsKG_edge_filter_df.to_csv(download_path_edge_file, sep ='\t', index=False)
# Out:
# /Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenomics_KG_parsed_edge_08_10_2026.tsv
