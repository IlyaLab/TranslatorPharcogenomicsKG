# %%
## Load necessary packages
import os
import pandas as pd
import glob
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

## Define the version number
version_number = "08_10_2026"
deployment_date = "2026-08-10"

# %%
## Load the Biolink category and predicate dictionary for mapping subject, object, and predicate types
# %run ./Biolink_category_and_predication_dictionary.ipynb
# Out:
# Date of last update:  2025-09-04
# Order is to always process Node/category map first, since the Edeg/predicate map depends on biolink-complainat node values
# -----------------------------------------------------------------------------------------------------------------------------
# Dictionary: category_map, Key template: Subject_category or Object_category
# ------------------------------------------------------------------------------------------
# Dictionary: predicate_map, Key template: (Subject_category, Object_category, Predicate)

# %% [markdown]
# ## Load files and convert them into separate node & edge files
# * check all imported file structure

# %%
## Notice!! Please change the file path of following codes into your own
raw_files_path = '/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/Open_targets_platform/'

## Define the output path for node & edge files after formatting
download_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/Open_targets_platform_parsed_node_{version_number}.tsv'
download_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/Open_targets_platform_parsed_edge_{version_number}.tsv'

# %%
import pandas as pd
import glob

files = glob.glob('/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/Open_targets_platform/association_by_datasource_direct/*.parquet')

# Read just one file's head as a quick look
df = pd.read_parquet(files[0])
print(df.head(20))
# print(df.dtypes)

# # Or read a fraction of all files combined
# df_sample = pd.concat([pd.read_parquet(f) for f in files[:2]])  # just first 2 files
# df_sample.sample(1000).to_csv('sample.csv', index=False)
# Out:
#       diseaseId         targetId aggregationType    aggregationValue  \
# 0   EFO_0000180  ENSG00000092847    datasourceId           europepmc
# 1   EFO_0000180  ENSG00000099785    datasourceId           europepmc
# 2   EFO_0000180  ENSG00000101916    datasourceId           europepmc
# 3   EFO_0000180  ENSG00000105851    datasourceId           europepmc
# 4   EFO_0000180  ENSG00000116001    datasourceId           europepmc
# 5   EFO_0000180  ENSG00000116785    datasourceId           europepmc
# 6   EFO_0000180  ENSG00000120217    datasourceId           europepmc
# 7   EFO_0000180  ENSG00000121807    datasourceId           europepmc
# 8   EFO_0000180  ENSG00000127507    datasourceId           europepmc
# 9   EFO_0000180  ENSG00000151360    datasourceId           europepmc
# 10  EFO_0000180  ENSG00000171195    datasourceId           europepmc
# 11  EFO_0000180  ENSG00000173163    datasourceId           europepmc
# 12  EFO_0000180  ENSG00000211891    datasourceId           europepmc
# ...
