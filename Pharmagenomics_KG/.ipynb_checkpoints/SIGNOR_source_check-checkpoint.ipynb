# %%
## Notice!! Please change the file path of following codes into your own
raw_files_path = '/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/SIGNOR/'

## Note! define download path in the very end of the notebook!!

# %%
## Check all node files being read
## Read all BigGIM node csv file in group 1
import os

for f in os.listdir(raw_files_path):
    if f.endswith('.tsv'):
        print(f)
# Out:
# all_data_11_09_25.tsv
# all_data_24_09_25.tsv

# %%
import pandas as pd

## Read each individual csv files
source_df = pd.read_csv(raw_files_path + 'all_data_24_09_25.tsv', sep='\t')

## check the length
print("current row number is: ", len(source_df))

## Drop nan values
source_df = source_df.dropna(subset=['ENTITYA', 'ENTITYB'])

## rename those columns into desired format
source_df.rename(columns={'ENTITYA': 'subject_name', 'TYPEA': 'subject_category', 'ENTITYB': 'object_name', 'TYPEB': 'object_category'}, inplace=True)

## replace phenotype labeling into biologicalProcess
source_df["subject_category"] = source_df["subject_category"].replace("phenotype", "BiologicalProcess")
source_df ["object_category"] = source_df["object_category"].replace("phenotype", "BiologicalProcess")

## replace all 'miR-34' to 'miR-34a' in two columns subject_category and object_category in the pandas dataframe
source_df['subject_name'] = source_df['subject_name'].replace('miR-34', 'miR-34a')
source_df['object_name'] = source_df['object_name'].replace('miR-34', 'miR-34a')

## remove those rows with category in fusion protein or stimulus from source_df for now, and expecting biolink team to add those new categories
source_df = source_df[(source_df['subject_category'] != 'fusion Protein') & (source_df['object_category'] != 'fusion Protein')]
source_df = source_df[(source_df['subject_category'] != 'stimulus') & (source_df['object_category'] != 'stimulus')]

## check the length after filtering
print("current row number is: ", len(source_df))

source_df.head(10)
# Out:
# current row number is:  40971
# current row number is:  40720
#    subject_name subject_category           IDA DATABASEA  \
# 0         RACK1          protein        P63244   UNIPROT
# 1   clenbuterol         chemical  CHEBI:174690     ChEBI
# 2          GYS2          protein        P54840   UNIPROT
# 3         GSK3B          protein        P49841   UNIPROT
# 4          GDNF          protein        P39905   UNIPROT
# 5       CSNK2A1          protein        P68400   UNIPROT
# 6         RPS15          protein        P62841   UNIPROT
# 7  CyclinB/CDK1          complex    SIGNOR-C17    SIGNOR
# 8          IL1B          protein        P01584   UNIPROT
# 9        PDZRN3          protein        Q9UPQ7   UNIPROT
#
#                              object_name object_category          IDB  \
# 0                                 PPP2CA         protein       P67775
# 1                                  ADRB1         protein       P08588
# 2                UDP-alpha-D-glucose(2-)        chemical  CHEBI:58885
# 3                                ZC3HAV1         protein       Q7Z2W4
# 4                                  NCAM1         protein       P13591
# 5                                  HMGA1         protein       P17096
# 6  40S cytosolic small ribosomal subunit         complex  SIGNOR-C286
# 7                                NDUFA12         protein       Q9UI09
# 8                                  STAT3         protein       P40763
# 9                                   MUSK         protein       O15146
#
#   DATABASEB                   EFFECT              MECHANISM  ... MODASEQ  \
# 0   UNIPROT    up-regulates activity                binding  ...     NaN
# 1   UNIPROT    up-regulates activity    chemical activation  ...     NaN
# 2     ChEBI  down-regulates quantity  chemical modification  ...     NaN
# 3   UNIPROT    up-regulates activity        phosphorylation  ...     NaN
# 4   UNIPROT    up-regulates activity                binding  ...     NaN
# 5   UNIPROT                  unknown        phosphorylation  ...     NaN
# 6    SIGNOR             form complex                binding  ...     NaN
# 7   UNIPROT    up-regulates activity        phosphorylation  ...     NaN
# 8   UNIPROT    up-regulates activity                    NaN  ...     NaN
# 9   UNIPROT  down-regulates quantity         ubiquitination  ...     NaN
#
#   MODIFICATIONB  MODBSEQ      PMID DIRECT NOTES  ANNOTATOR  \
# 0           NaN      NaN  24726876    YES   NaN     miannu
# 1           NaN      NaN  20590599    YES   NaN      Luana
# 2           NaN      NaN  26882899    YES   NaN     miannu
# 3           NaN      NaN  22514281    YES   NaN     miannu
# 4           NaN      NaN  15212950    YES   NaN     miannu
# 5           NaN      NaN   2806554    YES   NaN    llicata
# 6           NaN      NaN  25901680    YES   NaN  lperfetto
# 7           NaN      NaN  24746669    YES   NaN  lperfetto
# 8           NaN      NaN  32454942     NO   NaN     miannu
# 9           NaN      NaN  17576800    YES   NaN     miannu
#
#                                             SENTENCE  SCORE      SIGNOR_ID
# 0  RACK1 Mediates the Formation of the IRF3-RACK1...  0.200  SIGNOR-260945
# 1  Denopamine is the most selective ligand for β1...  0.800  SIGNOR-257862
# 2  Glycogenin initiates the first step of glycoge...  0.800  SIGNOR-267937
# 3  GSK3beta sequentially phosphorylated Ser 270, ...  0.200  SIGNOR-278402
# 4  Recently, NCAM was identified as an alternativ...  0.699  SIGNOR-252189
# 5  Sequence analysis of the native peptide (90-10...  0.331  SIGNOR-250894
# 6  Here we report the near-atomic structure of th...  0.904  SIGNOR-262437
# 7  Here, we show that a fraction of cyclin B1/Cdk...  0.200  SIGNOR-275595
# 8  IL-1β, an inflammatory cytokine primarily expr...  0.586  SIGNOR-263820
# 9  We have identified a PDZ domain containing RIN...  0.544  SIGNOR-271664
#
# [10 rows x 28 columns]

# %%
## check all unique combinations between subject & object
from itertools import combinations

# Get all combinations of 3 column names
col_combos = ['subject_category', 'object_category', 'EFFECT']

# Get unique combinations and their counts
combo_counts = source_df.groupby(col_combos).size().reset_index(name='count')

print(combo_counts)
# Out:
#       subject_category    object_category  \
# 0    BiologicalProcess  BiologicalProcess
# 1    BiologicalProcess  BiologicalProcess
# 2    BiologicalProcess            complex
# 3    BiologicalProcess            complex
# 4    BiologicalProcess            complex
# ..                 ...                ...
# 242      smallmolecule      proteinfamily
# 243      smallmolecule      proteinfamily
# 244      smallmolecule      smallmolecule
# 245      smallmolecule      smallmolecule
# 246      smallmolecule      smallmolecule
#
#                                   EFFECT  count
# 0                         down-regulates      3
# 1                           up-regulates     24
# 2                         down-regulates      2
# 3                down-regulates activity      1
# 4                           up-regulates      5
# ..                                   ...    ...
# 242                up-regulates activity     25
# 243  up-regulates quantity by expression      1
# 244                       down-regulates      1
# 245                         up-regulates      1
# 246                up-regulates quantity    424
#
# [247 rows x 4 columns]

# %%
## Define the output path for node & edge files after formatting
download_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/temp/SIGNOR_source_combos.tsv'

## download both node and edge files
## Download the result df
## disable download for testing
combo_counts.to_csv(download_path_node_file, sep ='\t', index=False)
