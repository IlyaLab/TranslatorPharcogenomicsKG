# %%
## Load necessary packages
import os
import pandas as pd
import glob
import numpy as np
import networkx as nx
# import matplotlib.pyplot as plt

## load the needed tqdm package
from tqdm import tqdm

# Enable tqdm for pandas apply
tqdm.pandas()

## Define the version number
## past versions:
## version_number = "08_18_2025"
## version_number = "09_04_2025"

## current version number
version_number = "01_06_2026"

# %%
## Define the output path for node & edge files after formatting
KG_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenomics_KG_parsed_node_{version_number}.tsv'
KG_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/wQualityControl/Pharmacogenomics_KG_parsed_edge_{version_number}.tsv'

# %%
import pandas as pd

## Read each individual csv files
source_node_df = pd.read_csv(KG_path_node_file, sep='\t')

# %%
## print the first 10 rows
source_node_df.head(10)
# Out:
#               id                    name      category gtopdb_ligand_type  \
# 0  RXCUI:2563966             Odevixibat   biolink:Drug                NaN
# 1  RXCUI:2571074            Maralixibat   biolink:Drug                NaN
# 2  RXCUI:2677894              Resmetirom  biolink:Drug                NaN
# 3  RXCUI:1313234            Triheptanoin  biolink:Drug                NaN
# 4  RXCUI:2672492              Zilucoplan  biolink:Drug                NaN
# 5  RXCUI:2642273   Rozanolixizumab-noli   biolink:Drug                NaN
# 6  RXCUI:2107316       Ravulizumab-cwvz   biolink:Drug                NaN
# 7  RXCUI:2587719  Efgartigimod Alfa-fcab  biolink:Drug                NaN
# 8   RXCUI:591781             Eculizumab   biolink:Drug                NaN
# 9  RXCUI:2675287               Nedosiran  biolink:Drug                NaN
#
#   gtopdb_species_type
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN

# %% [markdown]
# ### Obtain number of each node types in the current version of pharmacogenomics KG
# *

# %%
source_node_df['category'].value_counts()
# Out:
# category
# biolink:Gene                     20106
# biolink:Disease                  15925
# biolink:PhenotypicFeature        15273
# biolink:Drug                     10471
# biolink:ChemicalEntity            2265
# biolink:MacromolecularComplex      468
# biolink:SmallMolecule              466
# biolink:BiologicalProcess          209
# biolink:Protein                    126
# biolink:ProteinFamily               91
# biolink:MicroRNA                    24
# biolink:Pathway                      2
# biolink:Noncoding_RNAProduct         1
# Name: count, dtype: int64

# %% [markdown]
# ### Now get meta KG from edge files
# *

# %%
import pandas as pd

## Read each individual csv files
source_edge_df = pd.read_csv(KG_path_edge_file, sep='\t')
source_edge_df.head(10)
# Out:
# /var/folders/ml/cjwyk2ps62361rr96_3b_n080000gp/T/ipykernel_75139/3447422176.py:4: DtypeWarning: Columns (9,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   source_edge_df = pd.read_csv(KG_path_edge_file, sep='\t')
#          subject            subject_name subject_category         object  \
# 0  RXCUI:2563966             Odevixibat      biolink:Drug  NCBIGene:8647
# 1  RXCUI:2571074            Maralixibat      biolink:Drug  NCBIGene:8647
# 2  RXCUI:2571074            Maralixibat      biolink:Drug  NCBIGene:5244
# 3  RXCUI:2677894              Resmetirom     biolink:Drug  NCBIGene:9429
# 4  RXCUI:1313234            Triheptanoin     biolink:Drug  MONDO:0008723
# 5  RXCUI:2672492              Zilucoplan     biolink:Drug  NCBIGene:1134
# 6  RXCUI:2642273   Rozanolixizumab-noli      biolink:Drug  NCBIGene:1134
# 7  RXCUI:2107316       Ravulizumab-cwvz      biolink:Drug  NCBIGene:1134
# 8  RXCUI:2587719  Efgartigimod Alfa-fcab     biolink:Drug  NCBIGene:1134
# 9   RXCUI:591781             Eculizumab      biolink:Drug  NCBIGene:1134
#
#                                          object_name  object_category  \
# 0                                             ABCB11     biolink:Gene
# 1                                             ABCB11     biolink:Gene
# 2                                              ABCB4     biolink:Gene
# 3                                              ABCG2     biolink:Gene
# 4  ACADVL, CPT2, HADHA, HADHB (Long-Chain Fatty A...  biolink:Disease
# 5                                               ACHR     biolink:Gene
# 6                                               ACHR     biolink:Gene
# 7                                               ACHR     biolink:Gene
# 8                                               ACHR     biolink:Gene
# 9                                               ACHR     biolink:Gene
#
#                predicate                       knowledge_source  \
# 0  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 1  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 2  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 3  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 4  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 5  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 6  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 7  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 8  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
# 9  biolink:has_biomarker  FDA pharmacogenomics biomarkers table
#
#        knowledge_level            context_qualifier         agent_type  \
# 0  knowledge_assertion             Gastroenterology  text_mining_agent
# 1  knowledge_assertion             Gastroenterology  text_mining_agent
# 2  knowledge_assertion             Gastroenterology  text_mining_agent
# 3  knowledge_assertion             Gastroenterology  text_mining_agent
# 4  knowledge_assertion  Inborn Errors of Metabolism  text_mining_agent
# 5  knowledge_assertion                    Neurology  text_mining_agent
# 6  knowledge_assertion                Neurology      text_mining_agent
# 7  knowledge_assertion                    Neurology  text_mining_agent
# 8  knowledge_assertion                    Neurology  text_mining_agent
# 9  knowledge_assertion                    Neurology  text_mining_agent
#
#   deploy_date                                    id  \
# 0  2025-09-04  4e1f7def-7e8d-5204-9826-56887ff5ecb5
# 1  2025-09-04  d5f51f86-e8a1-5481-8105-cdd2d9efc023
# 2  2025-09-04  ef3537de-0846-5bf9-b22a-5541c4214210
# 3  2025-09-04  871b4518-e7db-5e9b-b5f8-c3ec2e4eed69
# 4  2025-09-04  92c91a1c-5cee-5fac-9962-a15a5800821b
# 5  2025-09-04  7bde8aa1-e508-5d70-b000-f779050e4c7c
# 6  2025-09-04  0f7f7a8e-a467-526b-a065-44d0eeb0508a
# 7  2025-09-04  8a61035a-c46d-5e33-a1b3-4adbc8c4272e
# 8  2025-09-04  8514da8f-7438-5365-b82e-4d82efb5cdb7
# 9  2025-09-04  f1438026-4ccf-5a8d-adc2-b5c5c24abb3b
#
#    subject_direction_qualifier object_direction_qualifier  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# 6                          NaN                        NaN
# 7                          NaN                        NaN
# 8                          NaN                        NaN
# 9                          NaN                        NaN
#
#   object_aspect_qualifier publications provided_by
# 0                     NaN          NaN         NaN
# 1                     NaN          NaN         NaN
# 2                     NaN          NaN         NaN
# 3                     NaN          NaN         NaN
# 4                     NaN          NaN         NaN
# 5                     NaN          NaN         NaN
# 6                     NaN          NaN         NaN
# 7                     NaN          NaN         NaN
# 8                     NaN          NaN         NaN
# 9                     NaN          NaN         NaN

# %%
# source_edge_df['knowledge_source'].value_counts()

source_edge_df['grouped_knowledge_source'] = source_edge_df['knowledge_source'].where(
    ~source_edge_df['knowledge_source'].str.startswith('SIGNOR'),
    'SIGNOR'
)

source_edge_df.groupby('grouped_knowledge_source').size()
# Out:
# grouped_knowledge_source
# FDA pharmacogenomics biomarkers table       542
# GtoPdB                                     4468
# PharmGKB                                  20958
# PrimeKG                                  954592
# SIGNOR                                    37030
# dtype: int64

# %%
source_edge_df['predicate'].value_counts()
# Out:
# predicate
# biolink:physical_interacts_with           642150
# biolink:has_phenotype                     111000
# biolink:broad_match                        86924
# biolink:genetically_associated_with        67034
# biolink:regulates                          25225
# biolink:has_contraindication               24962
# biolink:associated_with                    20958
# biolink:target_for                         16380
# biolink:affects                             9646
# biolink:DrugToGeneAssociation               4468
# biolink:GeneAffectsChemicalAssociation      3092
# biolink:treats                              2186
# biolink:in_complex_with                     2159
# biolink:can_be_carried_out_by                864
# biolink:has_biomarker                        542
# Name: count, dtype: int64

# %%
import pandas as pd

pd.set_option('display.max_rows', None)

source_edge_df.value_counts(
    ['subject_category', 'object_category', 'predicate']
).sort_values(ascending=False)
# Out:
# subject_category               object_category                predicate
# biolink:Gene                   biolink:Gene                   biolink:physical_interacts_with           642150
# biolink:Disease                biolink:PhenotypicFeature      biolink:has_phenotype                     111000
# biolink:Gene                   biolink:Disease                biolink:genetically_associated_with        63704
# biolink:Disease                biolink:Disease                biolink:broad_match                        49452
# biolink:PhenotypicFeature      biolink:PhenotypicFeature      biolink:broad_match                        37472
# biolink:Drug                   biolink:Disease                biolink:has_contraindication               24962
# biolink:Gene                   biolink:Gene                   biolink:regulates                          23007
#                                biolink:Drug                   biolink:target_for                         16380
#                                biolink:ChemicalEntity         biolink:associated_with                     5823
# biolink:ChemicalEntity         biolink:Gene                   biolink:associated_with                     5823
# biolink:Drug                   biolink:Gene                   biolink:DrugToGeneAssociation               4468
# biolink:Gene                   biolink:PhenotypicFeature      biolink:genetically_associated_with         3330
#                                biolink:Disease                biolink:associated_with                     3327
# biolink:Disease                biolink:Gene                   biolink:associated_with                     3327
# biolink:Gene                   biolink:Drug                   biolink:GeneAffectsChemicalAssociation      3092
#                                biolink:Gene                   biolink:associated_with                     2552
# biolink:ChemicalEntity         biolink:Gene                   biolink:affects                             2395
# biolink:Drug                   biolink:Disease                biolink:treats                              2186
# biolink:Gene                   biolink:MacromolecularComplex  biolink:in_complex_with                     2049
# biolink:MacromolecularComplex  biolink:Gene                   biolink:affects                             2044
# biolink:Gene                   biolink:BiologicalProcess      biolink:affects                             1141
# biolink:ProteinFamily          biolink:Gene                   biolink:regulates                           1129
# biolink:Gene                   biolink:SmallMolecule          biolink:affects                             1114
#                                biolink:Drug                   biolink:can_be_carried_out_by                864
#                                biolink:MacromolecularComplex  biolink:affects                              748
#                                biolink:ProteinFamily          biolink:regulates                            678
# biolink:SmallMolecule          biolink:Gene                   biolink:affects                              513
# biolink:Drug                   biolink:Gene                   biolink:has_biomarker                        506
# biolink:SmallMolecule          biolink:SmallMolecule          biolink:affects                              424
# biolink:MacromolecularComplex  biolink:BiologicalProcess      biolink:affects                              286
# biolink:Gene                   biolink:Protein                biolink:regulates                            161
# biolink:Protein                biolink:Gene                   biolink:regulates                            149
# biolink:MacromolecularComplex  biolink:SmallMolecule          biolink:affects                              143
#                                biolink:MacromolecularComplex  biolink:affects                              101
# biolink:ChemicalEntity         biolink:ChemicalEntity         biolink:associated_with                       84
# biolink:ProteinFamily          biolink:ProteinFamily          biolink:regulates                             69
# biolink:Gene                   biolink:ChemicalEntity         biolink:affects                               62
# biolink:ProteinFamily          biolink:BiologicalProcess      biolink:affects                               59
# biolink:ChemicalEntity         biolink:ProteinFamily          biolink:affects                               55
# biolink:MacromolecularComplex  biolink:ProteinFamily          biolink:affects                               53
# biolink:SmallMolecule          biolink:MacromolecularComplex  biolink:affects                               52
# biolink:ProteinFamily          biolink:MacromolecularComplex  biolink:affects                               47
# biolink:ChemicalEntity         biolink:MacromolecularComplex  biolink:affects                               44
# biolink:MacromolecularComplex  biolink:MacromolecularComplex  biolink:in_complex_with                       42
# biolink:SmallMolecule          biolink:BiologicalProcess      biolink:affects                               41
# biolink:MicroRNA               biolink:Gene                   biolink:affects                               38
# biolink:ProteinFamily          biolink:SmallMolecule          biolink:affects                               37
# biolink:SmallMolecule          biolink:ProteinFamily          biolink:affects                               32
# biolink:BiologicalProcess      biolink:Gene                   biolink:affects                               29
# biolink:Drug                   biolink:Gene                   biolink:affects                               29
#                                biolink:Disease                biolink:has_biomarker                         28
# biolink:ProteinFamily          biolink:MacromolecularComplex  biolink:in_complex_with                       26
# biolink:Protein                biolink:MacromolecularComplex  biolink:affects                               26
# biolink:MacromolecularComplex  biolink:Protein                biolink:affects                               24
# biolink:BiologicalProcess      biolink:BiologicalProcess      biolink:affects                               23
# biolink:Disease                biolink:Disease                biolink:associated_with                       22
# biolink:Gene                   biolink:MicroRNA               biolink:regulates                             21
# biolink:Protein                biolink:MacromolecularComplex  biolink:in_complex_with                       21
#                                biolink:BiologicalProcess      biolink:affects                               19
# biolink:SmallMolecule          biolink:MacromolecularComplex  biolink:in_complex_with                       13
# biolink:Protein                biolink:ProteinFamily          biolink:affects                               12
# biolink:BiologicalProcess      biolink:MacromolecularComplex  biolink:affects                                9
#                                biolink:SmallMolecule          biolink:affects                                8
# biolink:ChemicalEntity         biolink:MacromolecularComplex  biolink:in_complex_with                        7
# biolink:ProteinFamily          biolink:Protein                biolink:regulates                              7
# biolink:SmallMolecule          biolink:ChemicalEntity         biolink:affects                                7
# biolink:Drug                   biolink:PhenotypicFeature      biolink:has_biomarker                          6
# biolink:ChemicalEntity         biolink:SmallMolecule          biolink:affects                                6
# biolink:Protein                biolink:ProteinFamily          biolink:regulates                              4
# biolink:MicroRNA               biolink:BiologicalProcess      biolink:affects                                4
# biolink:BiologicalProcess      biolink:ProteinFamily          biolink:affects                                4
# biolink:SmallMolecule          biolink:Protein                biolink:affects                                4
# biolink:Noncoding_RNAProduct   biolink:Gene                   biolink:affects                                3
# biolink:MacromolecularComplex  biolink:MicroRNA               biolink:affects                                3
# biolink:Protein                biolink:Protein                biolink:affects                                2
#                                biolink:ChemicalEntity         biolink:affects                                2
# biolink:Drug                   biolink:Pathway                biolink:has_biomarker                          2
# biolink:MacromolecularComplex  biolink:ChemicalEntity         biolink:affects                                1
# biolink:Gene                   biolink:Gene                   biolink:in_complex_with                        1
# biolink:ChemicalEntity         biolink:BiologicalProcess      biolink:affects                                1
# biolink:MicroRNA               biolink:MacromolecularComplex  biolink:affects                                1
# Name: count, dtype: int64

# %% [markdown]
# ### Now create the meta KG

# %%
G = nx.from_pandas_edgelist( 
    source_edge_df, source='subject_category', target='object_category', edge_attr='predicate', create_using=nx.MultiDiGraph() 
)
print(G.is_directed())  # True
# Out:
# True

# %%
meta_edges_simple = (
    source_edge_df
    .groupby(['subject_category', 'object_category'])
    .agg({'predicate': lambda x: list(set(x))})
    .reset_index()
)

G = nx.DiGraph()

for _, row in meta_edges_simple.iterrows():
    G.add_edge(
        row['subject_category'],
        row['object_category'],
        predicates=row['predicate']
    )

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))

pos = nx.spring_layout(G, seed=42)

nx.draw(
    G, pos,
    with_labels=True,
    node_color='lightblue',
    node_size=2000,
    font_size=10,
    arrows=True
)

plt.show()
