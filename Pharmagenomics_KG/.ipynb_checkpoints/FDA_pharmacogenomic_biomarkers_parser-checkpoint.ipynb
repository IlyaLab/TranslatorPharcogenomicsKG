# %% [markdown]
# ## Parser for Table of Pharmacogenomic Biomarkers in Drug Labeling
# * obtained the source table here: https://www.fda.gov/drugs/science-and-research-drugs/table-pharmacogenomic-biomarkers-drug-labeling
# * last obtained timestamp: 06/25/2025
# * Content current as of: 09/23/2024
# * additiona information:

# %%
## To do list:
## Add

# %%
## Load necessary packages
import os
import pandas as pd
import glob
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

## Define the version number
version_number = "07_14_2025"
deployment_date = "2025-07-14"

# %%
## Load the Biolink category and predicate dictionary for mapping subject, object, and predicate types
# %run ./Biolink_category_and_predication_dictionary.ipynb
# Out:
# Date of last update:  2025-07-08
# Order is to always process Node/category map first, since the Edeg/predicate map depends on biolink-complainat node values
# -----------------------------------------------------------------------------------------------------------------------------
# Dictionary: category_map, Key template: Subject_category or Object_category
# ------------------------------------------------------------------------------------------
# Dictionary: predicate_map, Key template: (Subject_category, Object_category, Predicate)

# %% [markdown]
# ## Load files and convert them into separate node & edge files
# * check all imported file structure

# %%
## Notice!! Please change the file path of following codes into your own
raw_files_path = '/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/FDA_Pharmacogenomic_biomarkers_in_Drug_labeling/'

## Define the output path for node & edge files after formatting
download_path_node_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/FDA_Pharmacogenomic_biomarkers_parsed_node_{version_number}.tsv'
download_path_edge_file = f'/Users/Weiqi0/ISB_working/Ilya_lab/Translator/Pharmagenomics_KG/files/parsed/FDA_Pharmacogenomic_biomarkers_parsed_edge_{version_number}.tsv'

# %%
## Check all node files being read
## Read all BigGIM node csv file in group 1

for f in os.listdir(raw_files_path):
    if f.endswith('.csv'):
        print(f)
# Out:
# Table_of_Pharmacogenomic_Biomarkers_in_Drug_Labeling_FDA.csv

# %%
## Read each individual csv files
source_df = pd.read_csv(raw_files_path + 'Table_of_Pharmacogenomic_Biomarkers_in_Drug_Labeling_FDA.csv')
source_df.head(10)
# Out:
#                             Drug Therapeutic Area*  \
# 0  Articaine and Epinephrine (1)    Anesthesiology
# 1  Articaine and Epinephrine (2)    Anesthesiology
# 2                Bupivacaine (1)    Anesthesiology
# 3                Bupivacaine (2)    Anesthesiology
# 4             Chloroprocaine (1)    Anesthesiology
# 5             Chloroprocaine (2)    Anesthesiology
# 6                        Codeine    Anesthesiology
# 7                     Desflurane    Anesthesiology
# 8                     Isoflurane    Anesthesiology
# 9   Lidocaine and Prilocaine (1)    Anesthesiology
#
#                                           Biomarker†  \
# 0                                               G6PD
# 1         Nonspecific (Congenital Methemoglobinemia)
# 2                                               G6PD
# 3         Nonspecific (Congenital Methemoglobinemia)
# 4                                               G6PD
# 5         Nonspecific (Congenital Methemoglobinemia)
# 6                                             CYP2D6
# 7  CACNA1S, RYR1  (Genetic Susceptibility to Mali...
# 8  CACNA1S, RYR1  (Genetic Susceptibility to Mali...
# 9         Nonspecific (Congenital Methemoglobinemia)
#
#                                    Labeling Sections
# 0                           Warnings and Precautions
# 1                           Warnings and Precautions
# 2                                           Warnings
# 3                                           Warnings
# 4                                           Warnings
# 5                                           Warnings
# 6  Boxed Warning, Warnings and Precautions, Use i...
# 7  Contraindications, Warnings and Precautions, C...
# 8  Contraindications, Warnings, Clinical Pharmaco...
# 9                           Warnings and Precautions

# %%
## check unique node_type and their node_source
unique_node_type_values = source_df['Drug'].unique()
print("All possible drug types are here: " ,unique_node_type_values)
print("--------------------------------------------------------------------------")
print(len(unique_node_type_values))

unique_node_source_values = source_df['Biomarker†'].unique()
print("All possible biomarker are here: " ,unique_node_source_values)
print("--------------------------------------------------------------------------")
print(len(unique_node_source_values))
# Out:
# All possible drug types are here:  ['Articaine and Epinephrine (1)' 'Articaine and Epinephrine (2)'
#  'Bupivacaine (1)' 'Bupivacaine (2)' 'Chloroprocaine (1)'
#  'Chloroprocaine (2)' 'Codeine' 'Desflurane' 'Isoflurane'
#  'Lidocaine and Prilocaine (1)' 'Lidocaine and Prilocaine (2)'
#  'Lidocaine and Tetracaine (1)' 'Lidocaine and Tetracaine (2)'
#  'Lofexidine' 'Meloxicam' 'Mepivacaine (1)' 'Mepivacaine (2)' 'Mivacurium'
#  'Oliceridine' 'Oxymetazoline and Tetracaine (1)'
#  'Oxymetazoline and Tetracaine (2)' 'Ropivacaine (1)' 'Ropivacaine (2)'
#  'Sevoflurane' 'Succinylcholine (1)' 'Succinylcholine (2)' 'Tramadol'
#  'Carvedilol' 'Clopidogrel' 'Hydralazine' 'Isosorbide Dinitrate'
#  'Isosorbide Mononitrate' 'Mavacamten' 'Metoprolol' 'Nebivolol'
#  'Prasugrel (1)' 'Prasugrel (2)' 'Prasugrel (3)' 'Prasugrel (4)'
#  'Procainamide' 'Propafenone' 'Propranolol' 'Quinidine' 'Rivaroxaban'
#  'Tafamidis' 'Ticagrelor' 'Cevimeline' 'Abrocitinib' 'Dapsone (1)'
#  'Dapsone (2)' 'Fluorouracil (1)' 'Ustekinumab' 'Ascorbic Acid'
#  'Bempedoic Acid and Ezetimibe' 'Chlorpropamide' 'Evinacumab-dgnb (1)'
#  'Evolocumab (1)' 'Evolocumab (2)' 'Glimepiride' 'Glipizide' 'Glyburide'
#  'Levothyroxine' 'Lomitapide' 'Mecasermin' 'Metreleptin' 'Nateglinide'
#  'Pitavastatin' 'Rosuvastatin' 'Setmelanotide (1)' 'Setmelanotide (2)'
#  'Setmelanotide (3)' 'Tolazamide' 'Tolbutamide' 'Inclisiran'
#  'Evinacumab-dgnb (2)'
#  'Ascorbic Acid, PEG-3350, Potassium Chloride, Sodium Ascorbate, Sodium Chloride, and Sodium Sulfate'
#  'Dexlansoprazole' 'Dronabinol' 'Esomeprazole' 'Etrasimod' 'Givosiran'
#  'Lansoprazole' 'Maralixibat (1)' 'Maralixibat (2)' 'Maralixibat (3)'
#  'Maralixibat (4)' 'Maralixibat (5)' 'Maralixibat (6)'
#  'Metoclopramide (1)' 'Metoclopramide (2)' 'Metoclopramide (3)'
#  'Odevixibat (1)' 'Omeprazole' 'Ondansetron' 'Palonosetron' 'Pantoprazole'
#  'Rabeprazole' 'Resmetirom' 'Sulfasalazine (1)' 'Sulfasalazine (2)'
#  'Odevixibat (2) \xa0' 'Odevixibat (3)' 'Odevixibat (4)'
#  'Drospirenone and Ethinyl Estradiol' 'Elagolix'
#  'Estradiol and Progesterone (1)' 'Estradiol and Progesterone (2)'
#  'Estradiol and Progesterone (3)' 'Estradiol Valerate' 'Flibanserin (1)'
#  'Flibanserin (2)' 'Flibanserin (3)' 'Medroxyprogesterone'
#  'Ospemifene (1)' 'Ospemifene (2)' 'Synthetic Conjugated Estrogens, A (1)'
#  'Synthetic Conjugated Estrogens, A (2)'
#  'Synthetic Conjugated Estrogens, A (3)' 'Avatrombopag (1)'
#  'Avatrombopag (2)' 'Avatrombopag (3)' 'Avatrombopag (4)'
#  'Avatrombopag (5)' 'Avatrombopag (6)' 'Crizanlizumab-tmca'
#  'Desmopressin\xa0' 'Eltrombopag (1)' 'Eltrombopag (2)' 'Eltrombopag (3)'
#  'Eltrombopag (4)' 'Emapalumab-lzsg' 'Lenalidomide' 'Luspatercept–aamt'
#  'Lusutrombopag (1)' 'Lusutrombopag (2)' 'Lusutrombopag (3)'
#  'Lusutrombopag (4)' 'Lusutrombopag (5)' 'Mavorixafor' 'Methylene Blue'
#  'Mitapivat' 'Ropeginterferon Alfa-2b-njft' 'Succimer' 'Voxelotor'
#  'Warfarin (1)' 'Warfarin (2)' 'Warfarin (3)' 'Warfarin (4)'
#  'Alglucosidase Alfa' 'Betaine' 'Carglumic Acid' 'Cerliponase Alfa'
#  'Cholic Acid' 'Eliglustat' 'Elosulfase' 'Glycerol Phenylbutyrate (1)'
#  'Glycerol Phenylbutyrate (2)' 'Lonafarnib (1)' 'Lonafarnib (2)'
#  'Migalastat' 'Parathyroid Hormone' 'Sacrosidase' 'Sodium Phenylbutyrate'
#  'Triheptanoin' 'Abacavir' 'Boceprevir' 'Cabotegravir and Rilpivirine (1)'
#  'Cabotegravir and Rilpivirine (2)' 'Ceftriaxone (1)' 'Ceftriaxone (2)'
#  'Chloroquine' 'Daclatasvir' 'Dapsone (3)'
#  'Dasabuvir, Ombitasvir, Paritaprevir, and\xa0Ritonavir' 'Dolutegravir'
#  'Efavirenz' 'Elbasvir and Grazoprevir' 'Erythromycin and Sulfisoxazole'
#  'Hydroxychloroquine' 'Isoniazid, Pyrazinamide, and Rifampin'
#  'Ledipasvir and Sofosbuvir' 'Mafenide' 'Nalidixic Acid' 'Nitrofurantoin'
#  'Ombitasvir, Paritaprevir, and Ritonavir' 'Peginterferon Alfa-2b'
#  'Primaquine (1)' 'Primaquine (2)\xa0' 'Quinine Sulfate (1)'
#  'Quinine Sulfate (2)' 'Raltegravir' 'Simeprevir' 'Sofosbuvir'
#  'Sofosbuvir and Velpatasvir' 'Sofosbuvir, Velpatasvir, and Voxilaprevir'
#  'Sulfadiazine' 'Sulfamethoxazole and Trimethoprim (1)'
#  'Sulfamethoxazole and Trimethoprim (2)' 'Tafenoquine' 'Telaprevir'
#  'Voriconazole' 'Neomycin' 'Amikacin' 'Gentamicin' 'Plazomicin'
#  'Streptomycin' 'Tobramycin' 'Nedosiran' 'Aducanumab-avwa'
#  'Amifampridine Phosphate' 'Brivaracetam' 'Carbamazepine (1)'
#  'Carbamazepine (2)' 'Casimersen' 'Clobazam' 'Deutetrabenazine'
#  'Dextromethorphan and Quinidine' 'Diazepam' 'Donepezil' 'Eculizumab (1)'
#  'Eculizumab (2)' 'Efgartigimod Alfa-fcab' 'Eplontersen' 'Eteplirsen'
#  'Fosdenopterin' 'Fosphenytoin (1)' 'Fosphenytoin (2)\xa0' 'Galantamine'
#  'Ganaxolone' 'Golodirsen' 'Inebilizumab-cdon' 'Inotersen' 'Lacosamide'
#  'Meclizine' 'Nusinersen' 'Oxcarbazepine' 'Patisiran' 'Phenytoin (1)'
#  'Phenytoin (2)' 'Phenytoin (3)' 'Ravulizumab-cwvz (1)\xa0'
#  'Ravulizumab-cwvz (2)' 'Rimegepant' 'Risdiplam' 'Satralizumab-mwge'
#  'Siponimod' 'Sodium Oxybate' 'Tetrabenazine' 'Valbenazine'
#  'Valproic Acid (1)' 'Valproic Acid (2)' 'Viltolarsen' 'Vutrisiran'
#  'Zilucoplan' 'Lecanemab-irmb' 'Rozanolixizumab-noli (1)'
#  'Rozanolixizumab-noli (2)' 'Trofinetide' 'Abemaciclib (1)'
#  'Abemaciclib (2)' 'Abemaciclib (3)' 'Adagrasib'
#  'Ado-Trastuzumab Emtansine' 'Afatinib' 'Alectinib' 'Allopurinol'
#  'Alpelisib (1)\xa0' 'Alpelisib (2)' 'Alpelisib (3)' 'Amivantamab-vmjw'
#  'Anastrozole' 'Arsenic Trioxide' 'Asciminib' 'Atezolizumab (1)'
#  'Atezolizumab (2)\xa0\xa0' 'Atezolizumab (3)' 'Atezolizumab (4)'
#  'Atezolizumab (5)' 'Avapritinib (1)' 'Avapritinib (2)' 'Avelumab'
#  'Azacitidine (1)' 'Azacitidine (2)' 'Azacitidine (3)' 'Belinostat'
#  'Belzutifan (1)' 'Belzutifan (2)' 'Belzutifan (3)' 'Binimetinib (1)'
#  'Binimetinib (2)' 'Blinatumomab (1)' 'Blinatumomab (2)' 'Bosutinib'
#  'Brentuximab Vedotin (1)' 'Brentuximab Vedotin (2)' 'Brigatinib'
#  'Busulfan' 'Cabozantinib' 'Capecitabine (1)' 'Capecitabine (2)'
#  'Capivasertib (1)' 'Capivasertib (2)' 'Capivasertib (3)'
#  'Capivasertib (4)' 'Capivasertib (5)' 'Capmatinib' 'Cemiplimab-rwlc (1)'
#  'Cemiplimab-rwlc (2)' 'Cemiplimab-rwlc (3)' 'Cemiplimab-rwlc (4)'
#  'Ceritinib' 'Cetuximab (1)' 'Cetuximab (2)' 'Cetuximab (3)' 'Cisplatin'
#  'Cobimetinib' 'Crizotinib (1)' 'Crizotinib (2)' 'Dabrafenib (1)'
#  'Dabrafenib (2)' 'Dabrafenib (3)' 'Dacomitinib' 'Dasatinib'
#  'Denileukin Diftitox' 'Dinutuximab' 'Docetaxel' 'Dostarlimab-gxly'
#  'Durvalumab (3)' 'Durvalumab (4)' 'Duvelisib' 'Eflornithine'
#  'Elranatamab-bcmm (1)' 'Elranatamab-bcmm (2)' 'Elranatamab-bcmm (3)'
#  'Enasidenib' 'Encorafenib (1)' 'Encorafenib (2)' 'Entrectinib (1)'
#  'Entrectinib (2)' 'Erdafitinib (1)' 'Erdafitinib (2)\xa0' 'Eribulin (1)'
#  'Eribulin (2)' 'Erlotinib' 'Everolimus (1)' 'Everolimus (2)' 'Exemestane'
#  'Fam-Trastuzumab Deruxtecan-nxki (1)'
#  'Fam-Trastuzumab Deruxtecan-nxki (2)' 'Fluorouracil (2)' 'Flutamide'
#  'Fruquintinib' 'Fulvestrant (1)' 'Fulvestrant (2)' 'Futibatinib'
#  'Gefitinib (1)' 'Gefitinib (2)' 'Gilteritinib' 'Goserelin'
#  'Ibrutinib (1)' 'Ibrutinib (2)' 'Ibrutinib (3)' 'Imatinib (1)'
#  'Imatinib (2)' 'Imatinib (3)' 'Imatinib (4)' 'Inotuzumab Ozogamicin'
#  'Ipilimumab (1)' 'Ipilimumab (2)' 'Ipilimumab (3)' 'Ipilimumab (4)'
#  'Ipilimumab (5)' 'Irinotecan' 'Isatuximab- irfc (1)'
#  'Isatuximab- irfc (2)' 'Isatuximab- irfc (3)' 'Ivosidenib'
#  'Ixabepilone (1)' 'Ixabepilone (2)' 'Lapatinib (1)' 'Lapatinib (2)'
#  'Lapatinib (3)' 'Lapatinib (4)' 'Larotrectinib' 'Lenvatinib' 'Letrozole'
#  'Lorlatinib (1)' 'Lorlatinib (2)' 'Lutetium Lu 177 Dotatate'
#  'Lutetium Lu 177 Vipivotide Tetraxetan' 'Margetuximab-cmkb (1)'
#  'Margetuximab-cmkb (2)' 'Margetuximab-cmkb (3)' 'Margetuximab-cmkb (4)'
#  'Mercaptopurine (1)' 'Mercaptopurine (2)' 'Midostaurin (1)'
#  'Midostaurin (2)' 'Midostaurin (3)' 'Mirvetuximab Soravtansine-gynx'
#  'Mobocertinib' 'Neratinib (1)' 'Neratinib (2)' 'Nilotinib (1)'
#  'Nilotinib (2)' 'Niraparib' 'Nirogacestat (1)' 'Nirogacestat (2)'
#  'Nivolumab (1)' 'Nivolumab (2)' 'Nivolumab (3)' 'Nivolumab (4)'
#  'Nivolumab (5)' 'Nivolumab (6)' 'Nivolumab and Relatlimab-rmbw (1)'
#  'Nivolumab and Relatlimab-rmbw (2)' 'Nivolumab and Relatlimab-rmbw (3)'
#  'Obinutuzumab' 'Olaparib (1)' 'Olaparib (2)' 'Olaparib (3)'
#  'Olaparib (4)' 'Olaparib (5)' 'Olaparib (6)' 'Olaratumab' 'Olutasidenib'
#  'Omacetaxine' 'Osimertinib' 'Palbociclib (1)' 'Palbociclib (2)'
#  'Panitumumab (1)' 'Panitumumab (2)' 'Pazopanib (1)' 'Pazopanib (2)'
#  'Pembrolizumab (1)' 'Pembrolizumab (2)' 'Pembrolizumab (3)'
#  'Pembrolizumab (4)' 'Pembrolizumab (5)' 'Pembrolizumab (6)'
#  'Pembrolizumab (7)' 'Pemetrexed (1)' 'Pemetrexed (2)' 'Pemetrexed (3)'
#  'Pemigatinib (1)' 'Pemigatinib (2)' 'Pertuzumab (1)' 'Pertuzumab (2)'
#  'Pirtobrutinib (1)' 'Pirtobrutinib (2)' 'Pirtobrutinib (3)'
#  'Pirtobrutinib (4)' 'Pirtobrutinib (5)' 'Ponatinib' 'Pralsetinib'
#  'Quizartinib' 'Raloxifene' 'Ramucirumab (1)' 'Ramucirumab (2)'
#  'Rasburicase (1)' 'Rasburicase (2)' 'Regorafenib' 'Repotrectinib (1)'
#  'Repotrectinib (2)' 'Ribociclib (1)' 'Ribociclib (2)' 'Rituximab'
#  'Rucaparib (1)' 'Rucaparib (2)' 'Rucaparib (3)' 'Rucaparib (4)'
#  'Sacituzumab Govitecan-hziy (1)' 'Selpercatinib' 'Sotorasib'
#  'Talazoparib (1)' 'Talazoparib (2)' 'Tamoxifen (1)' 'Tamoxifen (2)'
#  'Tamoxifen (3)' 'Tamoxifen (4)' 'Tebentafusp-tebn' 'Teclistamab-cqyv (1)'
#  'Teclistamab-cqyv (2)' 'Teclistamab-cqyv (3)' 'Tepotinib (1)'
#  'Tepotinib (2)' 'Tepotinib (3)' 'Thioguanine (1)' 'Thioguanine (2)'
#  'Tipiracil and Trifluridine (1)' 'Tipiracil and Trifluridine (2)'
#  'Tislelizumab-jsgr' 'Toremifene' 'Tovorafenib' 'Trametinib (1)'
#  'Trametinib (2)' 'Trametinib (3)' 'Trastuzumab (1)' 'Trastuzumab (2)'
#  'Tremelimumab-actl (1)' 'Tremelimumab-actl (2)' 'Tremelimumab-actl (3)'
#  'Tretinoin' 'Tucatinib (1)' 'Vemurafenib (1)' 'Vemurafenib (2)'
#  'Venetoclax (1)' 'Venetoclax (2)' 'Venetoclax (3)' 'Venetoclax (4)'
#  'Venetoclax (5)' 'Venetoclax (6)' 'Venetoclax (7)' 'Venetoclax (8)'
#  'Vincristine' 'Zanubrutinib (1)' 'Durvalumab (2)' 'Tucatinib (2)'
#  'Polatuzumab Vedotin-piiq (1)' 'Durvalumab (1)' 'Elacestrant (1)'
#  'Elacestrant (2)' 'Mepolizumab' 'Polatuzumab Vedotin-piiq (2)'
#  'Polatuzumab Vedotin-piiq (3)' 'Sacituzumab Govitecan-hziy (2)'
#  'Sacituzumab Govitecan-hziy (3)' 'Sacituzumab Govitecan-hziy (4)'
#  'Tofersen' 'Tucatinib (3)' 'Zanubrutinib (2)' 'Zanubrutinib (3)'
#  'Talazoparib (3)' 'Gemtuzumab Ozogamicin' 'Amitriptyline' 'Amoxapine'
#  'Amphetamine' 'Aripiprazole' 'Aripiprazole Lauroxil' 'Atomoxetine'
#  'Brexpiprazole' 'Bupropion' 'Bupropion and Dextromethorphan\xa0'
#  'Cariprazine' 'Citalopram (1)' 'Citalopram (2)' 'Clomipramine'
#  'Clozapine' 'Desipramine' 'Desvenlafaxine' 'Doxepin (1)' 'Doxepin (2)'
#  'Duloxetine' 'Escitalopram (1)' 'Escitalopram (2)' 'Fluoxetine'
#  'Fluvoxamine' 'Iloperidone' 'Imipramine' 'Modafinil' 'Nefazodone'
#  'Nortriptyline' 'Paliperidone' 'Paroxetine' 'Perphenazine' 'Pimozide'
#  'Pitolisant' 'Protriptyline' 'Risperidone' 'Thioridazine\xa0'
#  'Trimipramine' 'Venlafaxine' 'Viloxazine (1)' 'Viloxazine (2)'
#  'Vortioxetine' 'Arformoterol (1)' 'Arformoterol (2)'
#  'Elexacaftor, Ivacaftor, and Tezacaftor' 'Formoterol (1)'
#  'Formoterol (2)' 'Indacaterol' 'Ivacaftor' 'Ivacaftor and Lumacaftor'
#  'Ivacaftor and Tezacaftor' 'Umeclidinium' 'Leniolisib (1)'
#  'Leniolisib (2)' 'Anakinra' 'Anifrolumab-fnia' 'Azathioprine (1)'
#  'Azathioprine (2)' 'Carisoprodol' 'Celecoxib' 'Flurbiprofen' 'Lesinurad'
#  'Pegloticase' 'Piroxicam' 'Probenecid' 'Upadacitinib'
#  'Sodium Nitrite (1)' 'Sodium Nitrite (2)' 'Mycophenolic Acid'
#  'Darifenacin' 'Fesoterodine' 'Lumasiran' 'Mirabegron' 'Tamsulosin'
#  'Tolterodine']
# --------------------------------------------------------------------------
# 608
# All possible biomarker are here:  ['G6PD' 'Nonspecific (Congenital Methemoglobinemia)' 'CYP2D6'
#  'CACNA1S, RYR1\xa0 (Genetic Susceptibility to Malignant Hyperthermia)'
#  'CYP2C9' 'BCHE' 'CYP2C19' 'Nonspecific (NAT)' 'CYB5R' 'CYP3A5' 'CYP2B6'
#  'F5 (Factor V Leiden)' 'TTR' 'DPYD' 'IL12A, IL12B, IL23A'
#  'Nonspecific (Heterozygous Familial Hypercholesterolemia)' 'LDLR'
#  'Nonspecific (Homozygous Familial Hypercholesterolemia)'
#  'Nonspecific (Congenital Hypothyroidism)' 'Nonspecific\xa0 (GH)' 'LEP'
#  'SLCO1B1' 'LEPR' 'PCSK1' 'POMC'
#  'CPOX, HMBS, PPOX (Acute Hepatic Porphyria)' 'JAG1' 'ABCB4' 'ABCB11'
#  'ATP8B1' 'MYO5B' 'TJP2' 'ABCG2' '\xa0ATP8B1\xa0\xa0 \xa0'
#  'JAG1\xa0\xa0 \xa0' 'NOTCH2\xa0\xa0 \xa0' 'PROC' 'PROS1'
#  'SERPINC1 (Antithrombin III)' 'ESR, PGR (Hormone Receptor)'
#  'ESR (Hormone Receptor)' 'F2 (Prothrombin)' 'HBB' 'F8' 'Chromosome 7'
#  'Chromosome 13'
#  'PRF1, RAB27A, SH2D1A, STXBP2, STX11, UNC13D, XIAP (Hemophagocytic Lymphohistiocytosis)'
#  'Chromosome 5q' 'CXCR4' 'PKLR' 'JAK2' 'VKORC1' 'GAA'
#  'CBS, MMADHC, MTHFR (Homocystinuria Deficiency)' 'NAGS' 'TPP1'
#  'AMACR, AKR1D1, CYP7A1, CYP27A1, DHCR7, HSD3B2 (Bile Acid Synthesis Disorders)'
#  'GALNS' 'ASS1, CPS1, OTC (Urea Cycle Disorders)' 'LMNA' 'ZMPSTE24' 'GLA'
#  'CASR' 'Nonspecific (Congenital Sucrase-Isomaltase Deficiency)'
#  'ACADVL, CPT2, HADHA, HADHB (Long-Chain Fatty Acid Oxidation Disorders)'
#  'HLA-B' 'IFNL3 (IL28B)' 'UGT1A1' 'MT-RNR1\xa0\xa0 \xa0' 'MT-RNR1\xa0\xa0'
#  'AGXT' 'APOE' 'NAT2' 'HLA-A' 'DMD' 'ACHR' 'AQP4' 'MOCS1' 'CDKL5' 'SMN2'
#  'SMN1, SMN2' 'ALDH5A1 (Succinic Semialdehyde Dehydrogenase Deficiency)'
#  'POLG' 'Nonspecific (Urea Cycle Disorders)' 'MUSK\xa0\xa0 \xa0' 'MECP2'
#  'ERBB2 (HER2)' 'MKI67' 'KRAS' 'EGFR' 'ALK' 'PIK3CA' 'PML-RARA'
#  'BCR-ABL1 (Philadelphia chromosome)' 'CD274 (PD-L1)'
#  'Gene Signature (T-effector)' 'BRAF' 'PDGFRA' 'KIT' 'CBL' 'PTPN11' 'RAS'
#  'UGT2B17' 'VHL' 'CD19' 'TNFRSF8 (CD30)' 'RET' 'AKT1' 'PTEN' 'MET' 'ROS1'
#  'TPMT' 'IL2RA (CD25 antigen)' 'MYCN'
#  'Microsatellite Instability, Mismatch Repair' 'Mismatch Repair'
#  'Chromosome 17p' 'Chromosome 4p;14q' 'Chromosome 14q;16q' 'IDH2' 'NTRK'
#  'FGFR3' 'FGFR2' 'FLT3' 'Chromosome 11q' 'MYD88' 'PDGFRB' 'FIP1L1-PDGFRA'
#  'IDH1' 'HLA-DQA1' 'HLA-DRB1' 'SSTR\xa0' 'FOLH1 (PSMA)' 'FCGR2A (CD32A)'
#  'FCGR2B (CD32B)' 'FCGR3A (CD16A)' 'NUDT15' 'NPM1' 'FOLR1'
#  'BRCA\xa0(Homologous Recombination Deficiency)' 'APC' 'CTNNB1' 'LAG3'
#  'MS4A1 (CD20 antigen)' 'BRCA'
#  'BRCA, Genomic Instability (Homologous Recombination Deficiency)'
#  'Homologous Recombination Repair' 'PPP2R2A' 'Tumor Mutational Burden'
#  'FGFR1' 'BTK' 'IGHV' 'TP53' 'CCDC6-RET, KIF5B-RET,\xa0 RET' 'CYP1A2'
#  'BRCA, Loss of Heterozygosity (Homologous Recombination Deficiency)'
#  'Microsatellite Instability, Mismatch Repair\xa0\xa0 \xa0'
#  'BCL2\xa0\xa0 \xa0' 'FIP1L1-PDGFRA\xa0\xa0 \xa0' 'BCL6\xa0\xa0 \xa0'
#  'MYC\xa0\xa0 \xa0' 'BRCA\xa0\xa0 \xa0' 'ESR (Hormone Receptor)\xa0\xa0'
#  'ERBB2 (HER2)\xa0\xa0 \xa0' 'SOD1' 'RAS\xa0\xa0 \xa0'
#  'Chromosome 17p\xa0\xa0' 'TP53\xa0\xa0 \xa0'
#  'Homologous Recombination Repair\xa0\xa0 \xa0' 'CD33' 'CFTR' 'PIK3CD'
#  'PIK3R1' 'NLRP3' 'Gene Signature (IFN)' 'HPRT1']
# --------------------------------------------------------------------------
# 176
