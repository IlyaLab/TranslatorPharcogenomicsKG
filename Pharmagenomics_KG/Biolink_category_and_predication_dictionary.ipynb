# %%
## The current date/version of the mapping dictionary
last_update = "2025-07-08"

# %%
## based on biolink categories visualization: https://biolink.github.io/biolink-model/categories.html
## create mapping dictionary between node & biolink named things

category_map = {
    'Drug': 'biolink:Drug',
    'drug': 'biolink:Drug',
    'Antibody': 'biolink:Drug', ## Potential new entity to raise for data ingest meeting
    
    'gene/protein': 'biolink:Gene',
    'Gene': 'biolink:Gene',
    'gene': 'biolink:Gene',

    'Cell': 'biolink:Cell',
    'cell': 'biolink:Cell',
    
    'Chemical': 'biolink:ChemicalEntity',
    'chemical': 'biolink:ChemicalEntity',

    'Complex': 'biolink:MacromolecularComplex',
    'complex': 'biolink:MacromolecularComplex',

    'Smallmolecule': 'biolink:SmallMolecule',

    'Disease': 'biolink:Disease', 
    'disease': 'biolink:Disease',
    
    'effect/phenotype': 'biolink:DiseaseOrPhenotypicFeature',

    'Phenotype': 'biolink:PhenotypicFeature',
    'phenotype': 'biolink:PhenotypicFeature',

    'Protein': 'biolink:Protein',
    'protein': 'biolink:Protein',
    'Fusion Protein': 'biolink:Protein', ## Potential new entity to raise for data ingest meeting
    
    'Proteinfamily': 'biolink:ProteinFamily',
    'proteinfamily': 'biolink:ProteinFamily',

    'Stimulus': 'biolink:EnvironmentalProcess',

    'Mirna': 'biolink:MicroRNA',

    'Ncrna': 'biolink:Noncoding_RNAProduct',
    
}

## based on biolink predicates visualization: https://biolink.github.io/biolink-model/predicates.html
## create mapping dictionary between edge & biolink predicates

predicate_map = {
    ('biolink:Gene', 'biolink:Gene', 'ppi'): 'biolink:physical_interacts_with',
    ('biolink:Gene', 'biolink:Drug', 'carrier'): 'biolink:can_be_carried_out_by',
    # 'enzyme': '', 
    ('biolink:Gene', 'biolink:Drug', 'target'): 'biolink:target_for',
    ('biolink:Gene', 'biolink:Drug', 'transporter'): 'biolink:GeneAffectsChemicalAssociation',
    ('biolink:Drug', 'biolink:Disease', 'contraindication'): 'biolink:has_contraindication',
    # 'indication': '',
    ('biolink:Drug', 'biolink:Disease', 'off-label use'): 'biolink:treats',
    # 'synergistic interaction': '',
    # 'associated with': 'biolink:associated_with',
    ('biolink:Disease', 'biolink:Disease', 'parent-child'): 'biolink:broad_match',
    # 'phenotype absent': '',
    ('biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'phenotype present'): 'biolink:has_phenotype',
    ('biolink:Drug', 'biolink:DiseaseOrPhenotypicFeature', 'side effect'): 'biolink:has_side_effect',

    ('biolink:Gene', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    # ('biolink:Gene', 'biolink:SmallMolecule', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Gene', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:EnvironmentalProcess', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    # ('biolink:MacromolecularComplex', 'biolink:SmallMolecule', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Protein', 'biolink:MicroRNA', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:MacromolecularComplex', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    # ('biolink:ProteinFamily', 'biolink:SmallMolecule', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:MacromolecularComplex', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    ('biolink:Drug', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates', # chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:Noncoding_RNAProduct', 'biolink:Gene', 'upregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates', ##chatgpt labeled
    # ('biolink:Gene', 'biolink:EnvironmentalProcess', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:PhenotypicFeature', 'biolink:Gene', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Gene', 'biolink:ChemicalEntity', 'upregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:ChemicalEntity', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates', #chatgpt labeled
    ('biolink:Protein', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:EnvironmentalProcess', 'biolink:SmallMolecule', 'upregulates'): 'biolink:regulates',
    ('biolink:SmallMolecule', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates',
    # ('biolink:Gene', 'biolink:MicroRNA', 'upregulates'): 'biolink:regulates', #chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:SmallMolecule', 'upregulates'): 'biolink:regulates',
    # ('biolink:Protein', 'biolink:EnvironmentalProcess', 'upregulates'): 'biolink:regulates', # chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:ProteinFamily', 'upregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:PhenotypicFeature', 'upregulates'): 'biolink:regulates',
    ('biolink:SmallMolecule', 'biolink:MacromolecularComplex', 'upregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:Protein', 'upregulates'): 'biolink:regulates',
    
    ('biolink:Gene', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    # ('biolink:Gene', 'biolink:SmallMolecule', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Gene', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:EnvironmentalProcess', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:Protein', 'downregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:Gene', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    # ('biolink:MacromolecularComplex', 'biolink:SmallMolecule', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Protein', 'biolink:MicroRNA', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:MacromolecularComplex', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    ('biolink:ChemicalEntity', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    # ('biolink:ProteinFamily', 'biolink:SmallMolecule', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:MacromolecularComplex', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    ('biolink:Drug', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    ('biolink:MacromolecularComplex', 'biolink:Protein', 'downregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates', # chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:Noncoding_RNAProduct', 'biolink:Gene', 'downregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates', ##chatgpt labeled
    # ('biolink:Gene', 'biolink:EnvironmentalProcess', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:PhenotypicFeature', 'biolink:Gene', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    # ('biolink:Gene', 'biolink:ChemicalEntity', 'downregulates'): 'biolink:regulates', ## chatgpt labeled
    ('biolink:ChemicalEntity', 'biolink:Protein', 'downregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:Protein', 'downregulates'): 'biolink:regulates',
    ('biolink:ProteinFamily', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    # ('biolink:PhenotypicFeature', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates', #chatgpt labeled
    ('biolink:Protein', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:EnvironmentalProcess', 'biolink:SmallMolecule', 'downregulates'): 'biolink:regulates',
    ('biolink:SmallMolecule', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates',
    # ('biolink:Gene', 'biolink:MicroRNA', 'downregulates'): 'biolink:regulates', #chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:SmallMolecule', 'downregulates'): 'biolink:regulates',
    # ('biolink:Protein', 'biolink:EnvironmentalProcess', 'downregulates'): 'biolink:regulates', # chatgpt labeled
    ('biolink:SmallMolecule', 'biolink:Protein', 'downregulates'): 'biolink:regulates',
    ('biolink:Protein', 'biolink:ProteinFamily', 'downregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:PhenotypicFeature', 'downregulates'): 'biolink:regulates',
    ('biolink:SmallMolecule', 'biolink:MacromolecularComplex', 'downregulates'): 'biolink:regulates',
    ('biolink:MicroRNA', 'biolink:Protein', 'downregulates'): 'biolink:regulates',

    ('biolink:Gene', 'biolink:Cell', 'expressed_in'): 'biolink:expressed_in',

    # ('biolink:Gene', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with', #chatgpt flagged
    ('biolink:ProteinFamily', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with',
    ('biolink:MacromolecularComplex', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with',
    ('biolink:SmallMolecule', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with',
    ('biolink:ChemicalEntity', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with',
    ('biolink:Protein', 'biolink:MacromolecularComplex', 'in_complex'): 'biolink:in_complex_with',
    # ('biolink:Gene', 'biolink:Gene', 'in_complex'): 'biolink:in_complex_with', ## chatgpt flagged

    ('biolink:Gene', 'biolink:Disease', 'associated'): 'biolink:associated_with',
    ('biolink:Gene', 'biolink:ChemicalEntity', 'associated'): 'biolink:associated_with',
    ('biolink:ChemicalEntity', 'biolink:Gene', 'associated'): 'biolink:associated_with',
    ('biolink:ChemicalEntity', 'biolink:ChemicalEntity', 'associated'): 'biolink:associated_with',
    ('biolink:Disease', 'biolink:Gene', 'associated'): 'biolink:associated_with',
    ('biolink:Gene', 'biolink:Gene', 'associated'): 'biolink:associated_with',
    ('biolink:Disease', 'biolink:Disease', 'associated'): 'biolink:associated_with',
}

## Old version for compatibility
# predicate_map = {
#     'ppi': 'biolink:physical_interacts_with',
#     'carrier': 'biolink:can_be_carried_out_by',
#     'enzyme': '', 
#     'target': 'biolink:target_for',
#     'transporter': 'biolink:GeneAffectsChemicalAssociation',
#     'contraindication': 'biolink:has_contraindication',
#     'indication': '',
#     'off-label use': 'biolink:treats',
#     'synergistic interaction': '',
#     # 'associated with': 'biolink:associated_with',
#     'parent-child': 'biolink:broad_match',
#     # 'phenotype absent': '',
#     'phenotype present': 'biolink:has_phenotype',
#     'side effect': 'biolink:has_side_effect',
# }

# %%
print("Date of last update: ", last_update)
print("Order is to always process Node/category map first, since the Edeg/predicate map depends on biolink-complainat node values")
print("-----------------------------------------------------------------------------------------------------------------------------")
print("Dictionary: category_map, Key template: Subject_category or Object_category")
print("------------------------------------------------------------------------------------------")
print("Dictionary: predicate_map, Key template: (Subject_category, Object_category, Predicate)")
# Out:
# Date of last update:  2025-07-08
# Order is to always process Node/category map first, since the Edeg/predicate map depends on biolink-complainat node values
# -----------------------------------------------------------------------------------------------------------------------------
# Dictionary: category_map, Key template: Subject_category or Object_category
# ------------------------------------------------------------------------------------------
# Dictionary: predicate_map, Key template: (Subject_category, Object_category, Predicate)
