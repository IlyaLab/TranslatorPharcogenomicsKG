# %%
## sample curl post
# curl -X 'POST' \
#   'http://multiomics.rtx.ai:8000/rebuild' \
#   -H 'accept: application/json' \
#   -H 'Content-Type: application/json' \
#   -H 'Authorization: Bearer detaillambhardshipbasket' \
#   -d '{
#    "branch": "multiomics"
# }'

# %%
#!pip install TCT

from TCT import node_normalizer
from TCT import name_resolver
from TCT import translator_metakg
from TCT import translator_kpinfo
from TCT import translator_query
from TCT import TCT

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json
import pandas as pd
import numpy as np

# %%
Translator_KP_info, APInames= translator_kpinfo.get_translator_kp_info()
print(len(Translator_KP_info))
# Step 2: Get metaKG and all predicates from Translator APIs through the SmartAPI system
metaKG = translator_metakg.get_KP_metadata(APInames) 
print(metaKG.shape)
# Add metaKG from Plover API based KG resources
APInames,metaKG = translator_metakg.add_plover_API(APInames, metaKG)
print(metaKG.shape)
    # Step 3: list metaKG information
All_predicates = list(set(metaKG['Predicate']))
All_categories = list((set(list(set(metaKG['Subject']))+list(set(metaKG['Object'])))))
API_withMetaKG = list(set(metaKG['API']))

# generate a dictionary of API and its predicates
API_predicates = {}
for api in API_withMetaKG:
    print(api)
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# Skipping server without x-maturity: {'url': '/sipr'}
# Skipping server without x-maturity: {'description': 'Local dev', 'url': 'http://127.0.0.1:5001'}
# Skipping server without x-maturity: {'description': 'Local dev', 'url': 'http://127.0.0.1:5001'}
# 59
# (11066, 5)
# (22606, 5)
# Automat-intact(Trapi v1.5.0)
# Multiomics KP - TRAPI 1.5.0
# MolePro
# Automat-monarchinitiative(Trapi v1.5.0)
# Automat-reactome(Trapi v1.5.0)
# Automat-pharos(Trapi v1.5.0)
# Connections Hypothesis Provider API
# Automat-viral-proteome(Trapi v1.5.0)
# Automat-hetionet(Trapi v1.5.0)
# Automat-genome-alliance(Trapi v1.5.0)
# Automat-hmdb(Trapi v1.5.0)
# Automat-string-db(Trapi v1.5.0)
# Gene-List Network Enrichment Analysis
# Automat-gtopdb(Trapi v1.5.0)
# Automat-gwas-catalog(Trapi v1.5.0)
# Automat-binding-db(Trapi v1.5.0)
# Automat-cam-kp(Trapi v1.5.0)
# Automat-hgnc(Trapi v1.5.0)
# Automat-ehr-may-treat-kp(Trapi v1.5.0)
# Text Mined Cooccurrence API
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0
# Automat-ehr-clinical-connections-kp(Trapi v1.5.0)
# Automat-human-goa(Trapi v1.5.0)
# Automat-icees-kg(Trapi v1.5.0)
# Clinical Trials KP - TRAPI 1.5.0
# Genetics Data Provider for NCATS Biomedical Translator Reasoners
# BioThings Explorer (BTE) TRAPI
# Service Provider TRAPI
# COHD TRAPI
# Automat-gtex(Trapi v1.5.0)
# RTX KG2 - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Automat-panther(Trapi v1.5.0)
# Automat-drug-central(Trapi v1.5.0)
# Drug Approvals KP - TRAPI 1.5.0
# Automat-ubergraph(Trapi v1.5.0)
# Automat-robokop(Trapi v1.5.0)
# Microbiome KP - TRAPI 1.5.0
# Automat-ctd(Trapi v1.5.0)
# Retriever

# %%
## Sanity check
import requests

url = 'https://amlkg.systemsbiology.org/AMLkg/meta_knowledge_graph'
response = requests.get(url)

print("Status code:", response.status_code)
print("Content-Type:", response.headers.get('Content-Type'))
print("Raw text (first 500 chars):")
print(response.text[:500])
# Out:
# Status code: 200
# Content-Type: application/json
# Raw text (first 500 chars):
# {"edges":[{"attributes":[{"attribute_type_id":"biolink:publications","constraint_name":"publications","constraint_use":true},{"attribute_type_id":"subject_category","constraint_name":"subject category","constraint_use":true},{"attribute_type_id":"knowledge_source","constraint_name":"knowledge source","constraint_use":true},{"attribute_type_id":"biolink:knowledge_level","constraint_name":"knowledge level","constraint_use":true},{"attribute_type_id":"object_category","constraint_name":"object cate

# %%
##############
## Note: this is the current correct way to call the API
###########
### Old, have issues
# APInames_sele = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'}
## New, no longer need to specify on port number
APInames_sele = {'AMLKG': 'https://amlkg.systemsbiology.org/AMLkg/query'}
selected_KGs = ['AMLKG']

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

APInames_plover, metaKG_plover = translator_metakg.add_plover_API(APInames_sele, metaKG_sele)

# %%
# print(metaKG_plover[metaKG_plover['API'] == 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0'])

# %%
print(metaKG_plover[metaKG_plover['API'] == 'AMLKG'])
# Out:
# Empty DataFrame
# Columns: [API, Predicate, Subject, Object, URL]
# Index: []

# %%
print(APInames_plover)
# Out:
# {'AMLKG': 'https://amlkg.systemsbiology.org/AMLkg/query', 'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query', 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query', 'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query', 'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query', 'Multiomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/multiomics/query', 'Microbiome KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/mbkp/query', 'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query'}

# %%
## add_plover_API() is hard-coded to existing KPs only!!
## need the general method to manually add the AMLKG kp

url = 'https://amlkg.systemsbiology.org/AMLkg/meta_knowledge_graph'
response = requests.get(url)
data = response.json()
for i in range(len(data["edges"])):
    APInames, metaKG = translator_metakg.add_new_API_for_query(APInames, metaKG, "AMLKG", "https://amlkg.systemsbiology.org:9990/AMLkg/query", data["edges"][i]['predicate'], data["edges"][i]['subject'], data["edges"][i]['object'])

# %%
print(APInames)
# Out:
# {'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query', 'ARAX Translator Reasoner - TRAPI 1.6.0': 'https://arax.transltr.io/api/arax/v1.4/query/', 'MolePro': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.5/query/', 'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query', 'BioThings Explorer (BTE) TRAPI': 'https://bte.transltr.io/v1/query/', 'Gene-List Network Enrichment Analysis': 'https://translator.broadinstitute.org/gelinea-trapi/v1.5/query/', 'Autonomous Relay System (ARS) TRAPI': 'https://ars-prod.transltr.io/ars/api/submit/', 'Automat-reactome(Trapi v1.5.0)': 'https://automat.renci.org/reactome/query/', 'Multiomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/multiomics/query', 'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query', 'Microbiome KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/mbkp/query', 'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query', 'Genetics Data Provider for NCATS Biomedical Translator Reasoners': 'https://genetics-kp.transltr.io/genetics_provider/trapi/v1.5/query/', 'Service Provider TRAPI': 'https://bte.transltr.io/v1/team/Service%20Provider/query/', 'Aragorn(Trapi v1.6.0)': 'https://aragorn.renci.org/aragorn/query/', 'COHD TRAPI': 'https://cohd-api.transltr.io/api/query/', 'mediKanren': 'https://medikanren-trapi.transltr.io/query/', 'Aragorn(Trapi v1.5.0)': 'https://aragorn.transltr.io/aragorn/query/', 'Text Mined Cooccurrence API': 'https://cooccurrence.ci.transltr.io/query/', 'Shepherd-arax(Trapi v1.5.0)': 'https://shepherd.ci.transltr.io/arax/query/', 'imProving Agent for TRAPI 1.5': 'https://ia.transltr.io/api/v1.5/query/', 'Knowledge Collaboratory API': 'https://collaboratory-api.transltr.io/query/', 'Automat-genome-alliance(Trapi v1.5.0)': 'https://automat.renci.org/genome-alliance/query/', 'Automat-drug-central(Trapi v1.5.0)': 'https://automat.renci.org/drugcentral/query/', 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query', 'SPOKE KP for TRAPI 1.5': 'https://spokekp.transltr.io/api/v1.5/query/', 'Automat-robokop(Trapi v1.5.0)': 'https://automat.transltr.io/robokopkg/query/', 'Shepherd-aragorn(Trapi v1.5.0)': 'https://shepherd.ci.transltr.io/aragorn/query/', 'Retriever': 'https://retriever.ci.transltr.io/query/', 'Automat-ctd(Trapi v1.5.0)': 'https://automat.renci.org/ctd/query/', 'Automat-pharos(Trapi v1.5.0)': 'https://automat.renci.org/pharos/query/', 'Automat-gwas-catalog(Trapi v1.5.0)': 'https://automat.renci.org/gwas-catalog/query/', 'Sri-node-normalizer(Trapi v1.5.0)': 'https://nodenorm.transltr.io/1.5/query/', 'Workflow-runner(Trapi v1.5.0)': 'https://translator-workflow-runner.transltr.io/query/', 'Shepherd-bte(Trapi v1.5.0)': 'https://shepherd.ci.transltr.io/bte/query/', 'Automat-human-goa(Trapi v1.5.0)': 'https://automat.renci.org/human-goa/query/', 'Automat-cam-kp(Trapi v1.5.0)': 'https://automat.transltr.io/cam-kp/query/', 'Shepherd SIPR': 'https://shepherd.renci.org/sipr/query/', 'Automat-gtopdb(Trapi v1.5.0)': 'https://automat.renci.org/gtopdb/query/', 'Sri-answer-appraiser(Trapi v1.5.0)': 'https://answerappraiser.transltr.io/query/', 'OpenPredict API': 'https://openpredict.transltr.io/query/', 'Answer-coalesce(Trapi v1.5.0)': 'https://answer-coalesce.transltr.io/query/', 'Automat-string-db(Trapi v1.5.0)': 'https://automat.renci.org/string-db/query/', 'Connections Hypothesis Provider API': 'https://chp-api.transltr.io/query/', 'Automat-binding-db(Trapi v1.5.0)': 'https://automat.renci.org/binding-db/query/', 'Automat-ehr-may-treat-kp(Trapi v1.5.0)': 'https://automat.renci.org/ehr-may-treat-kp/query/', 'Automat-gtex(Trapi v1.5.0)': 'https://automat.renci.org/gtex/query/', 'Automat-ubergraph(Trapi v1.5.0)': 'https://automat.renci.org/ubergraph/query/', 'Automat-panther(Trapi v1.5.0)': 'https://automat.renci.org/panther/query/', 'Automat-icees-kg(Trapi v1 ...

# %%
print(metaKG[metaKG['API'] == 'AMLKG'])
# Out:
#          API                                          Predicate  \
# 22606  AMLKG                               biolink:expressed_in
# 22607  AMLKG                                  biolink:regulates
# 22608  AMLKG                                  biolink:regulates
# 22609  AMLKG                                  biolink:regulates
# 22610  AMLKG                                  biolink:regulates
# 22611  AMLKG                                  biolink:regulates
# 22612  AMLKG                                  biolink:regulates
# 22613  AMLKG                                  biolink:regulates
# 22614  AMLKG                                  biolink:regulates
# 22615  AMLKG                                  biolink:regulates
# 22616  AMLKG                                  biolink:regulates
# 22617  AMLKG                                  biolink:regulates
# 22618  AMLKG                                  biolink:regulates
# 22619  AMLKG                                  biolink:regulates
# 22620  AMLKG                                  biolink:regulates
# 22621  AMLKG                                  biolink:regulates
# 22622  AMLKG                                  biolink:regulates
# 22623  AMLKG                                  biolink:regulates
# 22624  AMLKG                                  biolink:regulates
# 22625  AMLKG                                  biolink:regulates
# 22626  AMLKG                                  biolink:regulates
# 22627  AMLKG                            biolink:in_complex_with
# 22628  AMLKG                            biolink:in_complex_with
# 22629  AMLKG                                  biolink:regulates
# 22630  AMLKG                            biolink:in_complex_with
# 22631  AMLKG                                  biolink:regulates
# 22632  AMLKG                                  biolink:regulates
# 22633  AMLKG                            biolink:in_complex_with
# 22634  AMLKG                                  biolink:regulates
# 22635  AMLKG                                  biolink:regulates
# 22636  AMLKG                                  biolink:regulates
# 22637  AMLKG                                  biolink:regulates
# 22638  AMLKG                            biolink:in_complex_with
# 22639  AMLKG                                  biolink:regulates
# 22640  AMLKG                                  biolink:regulates
# 22641  AMLKG                                  biolink:regulates
# 22642  AMLKG                                  biolink:regulates
# 22643  AMLKG                                  biolink:regulates
# 22644  AMLKG                                  biolink:regulates
# 22645  AMLKG                                  biolink:regulates
# 22646  AMLKG                                  biolink:regulates
# 22647  AMLKG             biolink:associated_with_sensitivity_to
# 22648  AMLKG              biolink:associated_with_resistance_to
# 22649  AMLKG  biolink:GeneToDiseaseOrPhenotypicFeatureAssoci...
# 22650  AMLKG                                     biolink:treats
# 22651  AMLKG                                biolink:subclass_of
#
#                              Subject                         Object  \
# 22606                   biolink:Gene                   biolink:Cell
# 22607                   biolink:Gene                   biolink:Gene
# 22608  biolink:MacromolecularComplex                   biolink:Gene
# 22609  biolink:MacromolecularComplex      biolink:PhenotypicFeature
# 22610         biolink:ChemicalEntity                   biolink:Gene
# 22611                biolink:Protein                   biolink:Gene
# 22612                   biolink:Gene  biolink:MacromolecularComplex
# 22613          biolink:SmallMolecule                   biolink:Gene
# 22614          biolink:SmallMolecule          biolink:SmallMolecule
# 22615          biolink:SmallMolecule          biolink:ProteinFamily
# 22616          biolink:ProteinFamily                   biolink:Gene
# 22617   biolink:EnvironmentalProcess                   biolink:Gene
# 22618                   biolink:Gene      biolink:PhenotypicFeature
# 22619  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 22620                   biolink:Gene                biolink:Protein
# 22621          biolink:ProteinFamily          biolink:ProteinFamily
# 22622          biolink:ProteinFamily  biolink:MacromolecularComplex
# 22623         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 22624          biolink:SmallMolecule  biolink:MacromolecularComplex
# 22625  biolink:MacromolecularComplex                biolink:Protein
# 22626  biolink:MacromolecularComplex          biolink:ProteinFamily
# 22627          biolink:ProteinFamily  biolink:MacromolecularComplex
# 22628  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 22629                biolink:Protein      biolink:PhenotypicFeature
# 22630          biolink:SmallMolecule  biolink:MacromolecularComplex
# 22631         biolink:ChemicalEntity          biolink:ProteinFamily
# 22632               biolink:MicroRNA                   biolink:Gene
# 22633         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 22634          biolink:ProteinFamily      biolink:PhenotypicFeature
# 22635          biolink:SmallMolecule      biolink:PhenotypicFeature
# 22636                   biolink:Drug                   biolink:Gene
# 22637                biolink:Protein  biolink:MacromolecularComplex
# 22638                biolink:Protein  biolink:MacromolecularComplex
# 22639   biolink:Noncoding_RNAProduct                   biolink:Gene
# 22640                biolink:Protein          biolink:ProteinFamily
# 22641         biolink:ChemicalEntity                biolink:Protein
# 22642          biolink:ProteinFamily                biolink:Protein
# 22643   biolink:EnvironmentalProcess          biolink:SmallMolecule
# 22644          biolink:SmallMolecule                biolink:Protein
# 22645               biolink:MicroRNA      biolink:PhenotypicFeature
# 22646               biolink:MicroRNA                biolink:Protein
# 22647                   biolink:Gene                   biolink:Drug
# 22648                   biolink:Gene                   biolink:Drug
# 22649                   biolink:Gene                biolink:Disease
# 22650                   biolink:Drug                biolink:Disease
# 22651                biolink:Disease                biolink:Disease
#
#                                                      URL
# 22606  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22607  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22608  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22609  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22610  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22611  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22612  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22613  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22614  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22615  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22616  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22617  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22618  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22619  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22620  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22621  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22622  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22623  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22624  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22625  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22626  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22627  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22628  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22629  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22630  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22631  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22632  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22633  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22634  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22635  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22636  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22637  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22638  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22639  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22640  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22641  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22642  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22643  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22644  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22645  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22646  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22647  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22648  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22649  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22650  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 22651  https://amlkg.systemsbiology.org:9990/AMLkg/query

# %%
# print(API_predicates)

# %%
import networkx as nx
selected_KGs = ['AMLKG']

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

# build a multigraph to capture all edges (including duplicates) and their predicates
G = nx.MultiGraph()
for _, row in metaKG_sele.iterrows():
        G.add_edge(row['Subject'], row['Object'], predicate=row['Predicate'])

# layout and draw nodes + edges
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, k=0.5, iterations=20)
nx.draw(G, pos,
                with_labels=True,
                node_size=50,
                font_size=12,
                font_color='black',
                node_color='blue',
                edge_color='gray')

# draw edge labels
edge_labels = nx.get_edge_attributes(G, 'predicate')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)
plt.title('Interaction Graph of Subjects and Objects in metaKG')
plt.show()

# %%
# metaKG_sele

# %%
# APInames

# %%
## This is the step missing, generate a dictionary of API and remember to add the new AMLKG one into this dictionary!!

All_predicates = list(set(metaKG['Predicate']))
API_withMetaKG = list(set(metaKG['API']))

# generate a dictionary of API and its predicates
API_predicates = {}
for api in API_withMetaKG:
    print(api)
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# Automat-intact(Trapi v1.5.0)
# Multiomics KP - TRAPI 1.5.0
# MolePro
# Automat-monarchinitiative(Trapi v1.5.0)
# Automat-reactome(Trapi v1.5.0)
# Automat-pharos(Trapi v1.5.0)
# Connections Hypothesis Provider API
# Automat-viral-proteome(Trapi v1.5.0)
# Automat-hetionet(Trapi v1.5.0)
# Automat-genome-alliance(Trapi v1.5.0)
# Automat-hmdb(Trapi v1.5.0)
# Automat-string-db(Trapi v1.5.0)
# Gene-List Network Enrichment Analysis
# Automat-gtopdb(Trapi v1.5.0)
# Automat-gwas-catalog(Trapi v1.5.0)
# Automat-binding-db(Trapi v1.5.0)
# Automat-cam-kp(Trapi v1.5.0)
# Automat-hgnc(Trapi v1.5.0)
# Automat-ehr-may-treat-kp(Trapi v1.5.0)
# Text Mined Cooccurrence API
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0
# AMLKG
# Automat-ehr-clinical-connections-kp(Trapi v1.5.0)
# Automat-human-goa(Trapi v1.5.0)
# Automat-icees-kg(Trapi v1.5.0)
# Clinical Trials KP - TRAPI 1.5.0
# Genetics Data Provider for NCATS Biomedical Translator Reasoners
# BioThings Explorer (BTE) TRAPI
# Service Provider TRAPI
# COHD TRAPI
# Automat-gtex(Trapi v1.5.0)
# RTX KG2 - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Automat-panther(Trapi v1.5.0)
# Automat-drug-central(Trapi v1.5.0)
# Drug Approvals KP - TRAPI 1.5.0
# Automat-ubergraph(Trapi v1.5.0)
# Automat-robokop(Trapi v1.5.0)
# Microbiome KP - TRAPI 1.5.0
# Automat-ctd(Trapi v1.5.0)
# Retriever

# %%
# print(API_predicates)

# %%
## use neiborhood_finder


input_node_id, result, result_parsed, result_ranked_by_primary_infores = TCT.Neiborhood_finder('AML',
                                                                                            node2_categories = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity'],
                                                                                            ## check all APIs
                                                                                            # APInames = APInames,
                                                                                            # metaKG = metaKG,
                                                                                            ## example of checking specific API
                                                                                            #APInames = {'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query'},
                                                                                            # APInames = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'},
                                                                                            # metaKG = metaKG_sele,
                                                                                            APInames = APInames,
                                                                                            metaKG = metaKG,
                                                                                            API_predicates = API_predicates)
# Out:
# UMLS:C5777113
# 'AMLKG' generated an exception: HTTPSConnectionPool(host='amlkg.systemsbiology.org', port=9990): Max retries exceeded with url: /AMLkg/query (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1006)')))
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-hetionet(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-ctd(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-viral-proteome(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'MolePro' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-string-db(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-intact(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-binding-db(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-ubergraph(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-reactome(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-drug-central(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-human-goa(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-hmdb(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-cam-kp(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-robokop(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-monarchinitiative(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-icees-kg(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'RTX KG2 - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Service Provider TRAPI' generated an exception: argument of type 'NoneType' is not iterable
# 'Retriever' generated an exception: argument of type 'NoneType' is not iterable
# 'Text Mined Cooccurrence API' generated an exception: argument of type 'NoneType' is not iterable

# %%
# Step 8: Visualize the results
TCT.visulization_one_hop_ranking(result_ranked_by_primary_infores, result_parsed,
                                num_of_nodes = 50, input_query = input_node_id, 
                                fontsize = 5)

# %% [markdown]
# ## Now only those KPs by Plover
# *

# %%
# APInames_sele = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'}
# selected_KGs = ['AMLKG']

# metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

APInames_sele = {}
selected_KGs = []

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

APInames_plover, metaKG_plover = translator_metakg.add_plover_API(APInames_sele, metaKG_sele)

# %%
## add_plover_API() is hard-coded to existing KPs only!!
## need the general method to manually add the AMLKG kp

url = 'https://amlkg.systemsbiology.org/AMLkg/meta_knowledge_graph'
response = requests.get(url)
data = response.json()
for i in range(len(data["edges"])):
    APInames_plover, metaKG_plover = translator_metakg.add_new_API_for_query(APInames_plover, metaKG_plover, "AMLKG", "https://amlkg.systemsbiology.org:9990/AMLkg/query", data["edges"][i]['predicate'], data["edges"][i]['subject'], data["edges"][i]['object'])

# %%
# Translator_KP_info, APInames= translator_kpinfo.get_translator_kp_info()
from TCT import translator_kpinfo
from TCT import translator_metakg
from TCT import translator_query

API_predicates = translator_query.get_translator_API_predicates()
print(API_predicates)

# %%
print(APInames_plover)

# %%
## Note, previous missing step

## This is the step missing, generate a dictionary of API and remember to add the new AMLKG one into this dictionary!!

All_predicates = list(set(metaKG_plover['Predicate']))
API_withMetaKG = list(set(metaKG_plover['API']))

# generate a dictionary of API and its predicates
API_predicates_plover = {}
for api in API_withMetaKG:
    print(api)
    API_predicates_plover[api] = list(set(metaKG_plover[metaKG_plover['API'] == api]['Predicate']))

# %%
## use neiborhood_finder


input_node_id_amlkg, result_amlkg, result_parsed_amlkg, result_ranked_by_primary_infores_amlkg = TCT.Neiborhood_finder('AML',
                                                                                            node2_categories = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity'],
                                                                                            APInames = APInames_plover,
                                                                                            metaKG = metaKG_plover,
                                                                                            API_predicates = API_predicates_plover)

# %%
# Step 8: Visualize the results
TCT.visulization_one_hop_ranking(result_ranked_by_primary_infores_amlkg, result_parsed_amlkg,
                                num_of_nodes = 50, input_query = input_node_id_amlkg, 
                                fontsize = 5)
# Out:
# NodeNorm does not know about these identifiers: UNII:Q805XO2F7C,UNII:VS12X225PL,UNII:L4D9X59F34,UNII:ET4JC4S66E,UNII:Y8DGL9885E,UNII:O5V0F26RUW,UNII:475247QF1Z,UNII:OEN4982XNW,UNII:IZR558KO53,DRUGBANK:DB15060,UNII:3D2KVS9K7P,UNII:PVH8394DLN,UNII:3FXW1IW7WT,UNII:E6349B696W,UNII:RXG7T6RB8K,UNII:FR89SC8CT4,REACT:R-ALL-9692345
# [Text(0.5, 0, 'Gilteritinib'), Text(2.5, 0, 'Glasdegib'), Text(4.5, 0, 'Midostaurin'), Text(6.5, 0, 'Quizartinib'), Text(8.5, 0, 'Etoposide'), Text(10.5, 0, 'Doxorubicin'), Text(12.5, 0, 'mitoxantrone dihydrochloride'), Text(14.5, 0, 'Rituximab'), Text(16.5, 0, 'Gemtuzumab'), Text(18.5, 0, 'Tioguanine'), Text(20.5, 0, 'Hydroxyurea'), Text(22.5, 0, 'Busulfan'), Text(24.5, 0, 'Ascorbic acid'), Text(26.5, 0, 'Thalidomide'), Text(28.5, 0, 'Gemcitabine'), Text(30.5, 0, 'Fludarabine'), Text(32.5, 0, 'Bortezomib'), Text(34.5, 0, 'Topotecan'), Text(36.5, 0, 'Filgrastim'), Text(38.5, 0, 'purine-6-thiol'), Text(40.5, 0, 'Aclarubicin'), Text(42.5, 0, 'Posaconazole'), Text(44.5, 0, 'Deferasirox'), Text(46.5, 0, 'Pemigatinib'), Text(48.5, 0, 'Cyclosporine')]
# [Text(0.5, 0, 'Gilteritinib'), Text(2.5, 0, 'Glasdegib'), Text(4.5, 0, 'Midostaurin'), Text(6.5, 0, 'Quizartinib'), Text(8.5, 0, 'Etoposide'), Text(10.5, 0, 'Doxorubicin'), Text(12.5, 0, 'mitoxantrone dihydrochloride'), Text(14.5, 0, 'Rituximab'), Text(16.5, 0, 'Gemtuzumab'), Text(18.5, 0, 'Tioguanine'), Text(20.5, 0, 'Hydroxyurea'), Text(22.5, 0, 'Busulfan'), Text(24.5, 0, 'Ascorbic acid'), Text(26.5, 0, 'Thalidomide'), Text(28.5, 0, 'Gemcitabine'), Text(30.5, 0, 'Fludarabine'), Text(32.5, 0, 'Bortezomib'), Text(34.5, 0, 'Topotecan'), Text(36.5, 0, 'Filgrastim'), Text(38.5, 0, 'purine-6-thiol'), Text(40.5, 0, 'Aclarubicin'), Text(42.5, 0, 'Posaconazole'), Text(44.5, 0, 'Deferasirox'), Text(46.5, 0, 'Pemigatinib'), Text(48.5, 0, 'Cyclosporine')]
#                                                Gilteritinib  Ivosidenib  \
# biolink:affects                                           0           0
# biolink:in_clinical_trials_for                            1           1
# biolink:predisposes_to_condition                          0           0
# biolink:applied_to_treat                                  1           1
# biolink:treats_or_applied_or_studied_to_treat             1           1
# biolink:causes                                            0           0
# biolink:treats                                            1           1
# biolink:related_to                                        1           1
#
#                                                Glasdegib  Enasidenib  \
# biolink:affects                                        0           0
# biolink:in_clinical_trials_for                         1           1
# biolink:predisposes_to_condition                       0           0
# biolink:applied_to_treat                               1           1
# biolink:treats_or_applied_or_studied_to_treat          1           1
# biolink:causes                                         0           0
# biolink:treats                                         1           1
# biolink:related_to                                     1           1
#
#                                                Midostaurin  Azacitidine  \
# biolink:affects                                          0            0
# biolink:in_clinical_trials_for                           1            1
# biolink:predisposes_to_condition                         0            0
# biolink:applied_to_treat                                 1            1
# biolink:treats_or_applied_or_studied_to_treat            0            0
# biolink:causes                                           0            0
# biolink:treats                                           1            1
# biolink:related_to                                       1            1
#
#                                                Quizartinib  Decitabine  \
# biolink:affects                                          0           1
# biolink:in_clinical_trials_for                           1           1
# biolink:predisposes_to_condition                         0           0
# biolink:applied_to_treat                                 1           1
# biolink:treats_or_applied_or_studied_to_treat            1           0
# biolink:causes                                           0           0
# biolink:treats                                           1           1
# biolink:related_to                                       0           0
#
#                                                Etoposide  \
# biolink:affects                                        0
# biolink:in_clinical_trials_for                         1
# biolink:predisposes_to_condition                       0
# biolink:applied_to_treat                               1
# biolink:treats_or_applied_or_studied_to_treat          1
# biolink:causes                                         1
# biolink:treats                                         0
# biolink:related_to                                     1
#
#                                                Idarubicin hydrochloride  ...  \
# biolink:affects                                                       0  ...
# biolink:in_clinical_trials_for                                        0  ...
# biolink:predisposes_to_condition                                      0  ...
# biolink:applied_to_treat                                              1  ...
# biolink:treats_or_applied_or_studied_to_treat                         0  ...
# biolink:causes                                                        0  ...
# biolink:treats                                                        0  ...
# biolink:related_to                                                    1  ...
#
#                                                Antioxidants  \
# biolink:affects                                           0
# biolink:in_clinical_trials_for                            0
# biolink:predisposes_to_condition                          0
# biolink:applied_to_treat                                  0
# biolink:treats_or_applied_or_studied_to_treat             1
# biolink:causes                                            0
# biolink:treats                                            0
# biolink:related_to                                        0
#
#                                                Antigens, Surface  \
# biolink:affects                                                0
# biolink:in_clinical_trials_for                                 0
# biolink:predisposes_to_condition                               0
# biolink:applied_to_treat                                       0
# biolink:treats_or_applied_or_studied_to_treat                  0
# biolink:causes                                                 0
# biolink:treats                                                 0
# biolink:related_to                                             1
#
#                                                Antigens, Differentiation  \
# biolink:affects                                                        0
# biolink:in_clinical_trials_for                                         0
# biolink:predisposes_to_condition                                       0
# biolink:applied_to_treat                                               0
# biolink:treats_or_applied_or_studied_to_treat                          0
# biolink:causes                                                         0
# biolink:treats                                                         0
# biolink:related_to                                                     1
#
#                                                Antigens  \
# biolink:affects                                       0
# biolink:in_clinical_trials_for                        0
# biolink:predisposes_to_condition                      0
# biolink:applied_to_treat                              0
# biolink:treats_or_applied_or_studied_to_treat         0
# biolink:causes                                        0
# biolink:treats                                        0
# biolink:related_to                                    1
#
#                                                Antibodies, Monoclonal  \
# biolink:affects                                                     0
# biolink:in_clinical_trials_for                                      0
# biolink:predisposes_to_condition                                    0
# biolink:applied_to_treat                                            0
# biolink:treats_or_applied_or_studied_to_treat                       1
# biolink:causes                                                      0
# biolink:treats                                                      0
# biolink:related_to                                                  1
#
#                                                Antibodies, Anti-Idiotypic  \
# biolink:affects                                                         0
# biolink:in_clinical_trials_for                                          0
# biolink:predisposes_to_condition                                        0
# biolink:applied_to_treat                                                0
# biolink:treats_or_applied_or_studied_to_treat                           0
# biolink:causes                                                          0
# biolink:treats                                                          0
# biolink:related_to                                                      1
#
#                                                Antibodies  \
# biolink:affects                                         0
# biolink:in_clinical_trials_for                          0
# biolink:predisposes_to_condition                        0
# biolink:applied_to_treat                                0
# biolink:treats_or_applied_or_studied_to_treat           0
# biolink:causes                                          0
# biolink:treats                                          0
# biolink:related_to                                      1
#
#                                                Anthracycline Antibiotics  \
# biolink:affects                                                        0
# biolink:in_clinical_trials_for                                         0
# biolink:predisposes_to_condition                                       0
# biolink:applied_to_treat                                               0
# biolink:treats_or_applied_or_studied_to_treat                          1
# biolink:causes                                                         0
# biolink:treats                                                         0
# biolink:related_to                                                     0
#
#                                                Antibiotics  Micafungin
# biolink:affects                                          0           0
# biolink:in_clinical_trials_for                           0           1
# biolink:predisposes_to_condition                         0           0
# biolink:applied_to_treat                                 0           0
# biolink:treats_or_applied_or_studied_to_treat            1           0
# biolink:causes                                           0           0
# biolink:treats                                           0           0
# biolink:related_to                                       0           0
#
# [8 rows x 618 columns]

# %%
paths, input_node1_id, input_node2_id, result1, result2, result_parsed1, result_parsed2, result_ranked_by_primary_infores1, result_ranked_by_primary_infores2 = TCT.Path_finder('AML', 
                                                                                                                                                                                'TP53', 
                                                                                                                                                                                ['biolink:Drug', 'biolink:SmallMolecule', 'biolink:ChemicalEntity'], 
                                                                                                                                                                                APInames=APInames_plover, 
                                                                                                                                                                                metaKG=metaKG_plover, 
                                                                                                                                                                                API_predicates=API_predicates_plover)
# Out:
# MONDO:0018874
# NCBIGene:7157
# AMLKG: Success!
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!
# AMLKG: Success!
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0: Success!
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# NodeNorm does not know about these identifiers: DRUGBANK:DB15060,REACT:R-ALL-9692345,UNII:FR89SC8CT4,UNII:3D2KVS9K7P,UNII:PVH8394DLN,UNII:3FXW1IW7WT,UNII:RXG7T6RB8K,UNII:E6349B696W,UNII:ET4JC4S66E,UNII:Y8DGL9885E,UNII:475247QF1Z,UNII:O5V0F26RUW,UNII:Q805XO2F7C,UNII:VS12X225PL,UNII:L4D9X59F34,UNII:IZR558KO53,UNII:OEN4982XNW
# CHEMBL.COMPOUND:CHEMBL1522984: no preferred name
# CHEMBL.COMPOUND:CHEMBL1702181: no preferred name
# CHEMBL.COMPOUND:CHEMBL580421: no preferred name
# CHEMBL.COMPOUND:CHEMBL1303948: no preferred name
# CHEMBL.COMPOUND:CHEMBL591126: no preferred name
# CHEMBL.COMPOUND:CHEMBL1389794: no preferred name
# NodeNorm does not know about these identifiers: ChEBI:CHEBI:94980,ChEBI:CHEBI:45307,ChEBI:CHEBI:91326,PUBCHEM:CID:216345,PUBCHEM.COMPOUND:<NA>,PUBCHEM.COMPOUND:<NA>,UMLS:C0018282,DRUGBANK:DB15060,UMLS:C0018282,DRUGBANK:DB15060,CHEBI:232616,ttd.target:ISA-P53-01,CHEBI:232328,NCIT:C28310
# Number of possible paths:  93
# NodeNorm does not know about these identifiers: DRUGBANK:DB15060
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.11/site-packages/TCT/TCT.py:1517: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="center", fontsize=fontsize)

# %%
paths.head(5)
# Out:
#                             score  output_node  \
# Daunorubicin hydrochloride   0.75  CHEBI:31456
# Methotrexate                 0.50  CHEBI:44185
# Bortezomib                   0.50  CHEBI:52717
# Topotecan                    0.50  CHEBI:63632
# Azacitidine                  0.50   CHEBI:2038
#
#                                                                    predictes1  \
# Daunorubicin hydrochloride  biolink:applied_to_treat; biolink:affects; bio...
# Methotrexate                biolink:applied_to_treat; biolink:in_clinical_...
# Bortezomib                  biolink:treats_or_applied_or_studied_to_treat;...
# Topotecan                   biolink:treats_or_applied_or_studied_to_treat;...
# Azacitidine                 biolink:applied_to_treat; biolink:related_to; ...
#
#                                                                    predictes2  \
# Daunorubicin hydrochloride                   biolink:affects; biolink:affects
# Methotrexate                                 biolink:affects; biolink:affects
# Bortezomib                  biolink:interacts_with; biolink:affects; bioli...
# Topotecan                                    biolink:affects; biolink:affects
# Azacitidine                                                   biolink:affects
#
#                                       output_node_name
# Daunorubicin hydrochloride  Daunorubicin hydrochloride
# Methotrexate                              Methotrexate
# Bortezomib                                  Bortezomib
# Topotecan                                    Topotecan
# Azacitidine                                Azacitidine

# %%
forplot = TCT.visulize_path(input_node1_id, name_resolver.lookup('Bortezomib').curie, input_node2_id, result1, result2)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola', 'title': 'Path', 'nodeSpacing': 80, 'edgeLengthVal': 50}, cy…

# %% [markdown]
# ### Following are step by step breakdown codes to understand the execption issue
# *

# %%
## test step by step of the TCT.Neiborhood_finder to see which step is failling

from TCT import name_resolver
from TCT import translator_metakg
from TCT import translator_kpinfo
from TCT import translator_query

from TCT import node_normalizer
from TCT import TCT

input_node = 'AML'
input_node_category = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']
APInames = APInames_plover
metaKG = metaKG_plover
API_predicates = API_predicates

# Step 1: Resolve the input node to get its curie id and categories
input_node_info = name_resolver.lookup(input_node)
input_node_id = input_node_info.curie
print(input_node_id)
    
if len(input_node_category) == 0:
    input_node_category = input_node_info.types 
else:
    input_node_category = list(set(input_node_category).intersection(set(input_node_info.types)))
    if len(input_node_category) == 0:
        input_node_category = input_node_info.types
# Out:
# MONDO:0018874

# %%
## one issue need to load this API function
from TCT import sele_predicates_API

# Step 2: Select predicates and APIs based on the intermediate categories
sele_predicates, sele_APIs, API_URLs = sele_predicates_API(input_node_category,
                                                            node2_categories,
                                                            metaKG, APInames)

# %%
API_URLs
# Out:
# ['https://multiomics.rtx.ai:9990/mbkp/query',
#  'https://multiomics.rtx.ai:9990/multiomics/query',
#  'https://kg2cploverdb.ci.transltr.io/kg2c/query',
#  'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query',
#  'https://multiomics.rtx.ai:9990/ctkp/query',
#  'https://amlkg.systemsbiology.org:9990/AMLkg/query',
#  'https://multiomics.rtx.ai:9990/dakp/query']

# %%
from TCT import format_query_json
# Step 3: Format the query JSON for the input node
query_json = format_query_json([input_node_id], [], 
                                [input_node_category], 
                                node2_categories, 
                                sele_predicates)

# %%
query_json
# Out:
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01',
#      'object': 'n00',
#      'predicates': ['biolink:contributes_to',
#       'biolink:produces',
#       'biolink:has_side_effect',
#       'biolink:coexists_with',
#       'biolink:exacerbates_condition',
#       'biolink:preventative_for_condition',
#       'biolink:chemically_similar_to',
#       'biolink:drug_regulatory_status_world_wide',
#       'biolink:applied_to_treat',
#       'biolink:precedes',
#       'biolink:disrupts',
#       'biolink:physically_interacts_with',
#       'biolink:gene_associated_with_condition',
#       'biolink:associated_with',
#       'biolink:contraindicated_in',
#       'biolink:interacts_with',
#       'biolink:manifestation_of',
#       'biolink:affects',
#       'biolink:predisposes_to_condition',
#       'biolink:treats',
#       'biolink:close_match',
#       'biolink:biomarker_for',
#       'biolink:actively_involved_in',
#       'biolink:composed_primarily_of',
#       'biolink:has_member',
#       'biolink:has_output',
#       'biolink:exact_match',
#       'biolink:in_clinical_trials_for',
#       'biolink:subclass_of',
#       'biolink:located_in',
#       'biolink:has_input',
#       'biolink:has_participant',
#       'biolink:occurs_in',
#       'biolink:treats_or_applied_or_studied_to_treat',
#       'biolink:is_sequence_variant_of',
#       'biolink:same_as',
#       'biolink:correlated_with',
#       'biolink:causes',
#       'biolink:related_to',
#       'biolink:has_part',
#       'biolink:derives_from']}},
#    'nodes': {'n00': {'ids': ['MONDO:0018874']},
#     'n01': {'categories': ['biolink:SmallMolecule',
#       'biolink:Drug',
#       'biolink:ChemicalEntity']}}}}}

# %%
from TCT import translator_query
from TCT import parse_KG
# Step 4: Query the APIs in parallel
result = translator_query.parallel_api_query(query_json=query_json, 
                            select_APIs= sele_APIs, 
                            APInames=APInames,
                            API_predicates=API_predicates,
                            max_workers=len(sele_APIs))
result_parsed = parse_KG(result)
# Out:
# 'AMLKG' generated an exception: 'AMLKG'
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!

# %%
## ok, step 4 get the exception, now break down step 4 parallel_api_query function to further id the issue
# Parallel query
result = []
from concurrent.futures import ThreadPoolExecutor, as_completed
from copy import deepcopy
from TCT.translator_query import query_KP

query_json=query_json
select_APIs= sele_APIs
APInames=APInames
API_predicates=API_predicates
max_workers=len(sele_APIs)

with ThreadPoolExecutor(max_workers=max_workers) as executor:

    # copy the query_json for each API to avoid modifying the original query_json
    query_json_cur = deepcopy(query_json)
    # print(query_json_cur)

    for API_name_cur in select_APIs:
         print(API_name_cur)
    
    future_to_url = {executor.submit(query_KP, API_name_cur, query_json_cur, APInames, API_predicates): API_name_cur for API_name_cur in select_APIs}

    # for future in as_completed(future_to_url):
    #     url = future_to_url[future]
    #     try:
    #         data = future.result()
    #         if 'knowledge_graph' in data:
    #             result.append(data)
    #     except Exception as exc:
    #         print('%r generated an exception: %s' % (url, exc))
# Out:
# Microbiome KP - TRAPI 1.5.0
# Multiomics KP - TRAPI 1.5.0
# RTX KG2 - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Clinical Trials KP - TRAPI 1.5.0
# AMLKG
# Drug Approvals KP - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!

# %%
## Now the issue found, it isn't even execute for amlkg
## now break down the query_kp()
from TCT.translator_query import optimize_query_json

## working one
API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

## aml kg one
# API_name_cur = 'AMLKG'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
# print(query_copy)
## optimize on our private copy
query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
print(query_json_cur)
response = requests.post(API_url_cur, json=query_json_cur)
print(response)
# Out:
# https://multiomics.rtx.ai:9990/dakp/query
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01', 'object': 'n00', 'predicates': ['biolink:applied_to_treat', 'biolink:treats']}}, 'nodes': {'n00': {'ids': ['MONDO:0018874']}, 'n01': {'categories': ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']}}}}}
# <Response [200]>

# %%
## Now the issue found, it isn't even execute for amlkg
## now break down the query_kp()
from TCT.translator_query import optimize_query_json

## working one
# API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

## aml kg one
API_name_cur = 'AMLKG'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
print(query_copy)
## optimize on our private copy
query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
print(query_json_cur)
response = requests.post(API_url_cur, json=query_json_cur)
print(response)
# Out:
# https://amlkg.systemsbiology.org:9990/AMLkg/query
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01', 'object': 'n00', 'predicates': ['biolink:contributes_to', 'biolink:produces', 'biolink:has_side_effect', 'biolink:coexists_with', 'biolink:exacerbates_condition', 'biolink:preventative_for_condition', 'biolink:chemically_similar_to', 'biolink:drug_regulatory_status_world_wide', 'biolink:applied_to_treat', 'biolink:precedes', 'biolink:disrupts', 'biolink:physically_interacts_with', 'biolink:gene_associated_with_condition', 'biolink:associated_with', 'biolink:contraindicated_in', 'biolink:interacts_with', 'biolink:manifestation_of', 'biolink:affects', 'biolink:predisposes_to_condition', 'biolink:treats', 'biolink:close_match', 'biolink:biomarker_for', 'biolink:actively_involved_in', 'biolink:composed_primarily_of', 'biolink:has_member', 'biolink:has_output', 'biolink:exact_match', 'biolink:in_clinical_trials_for', 'biolink:subclass_of', 'biolink:located_in', 'biolink:has_input', 'biolink:has_participant', 'biolink:occurs_in', 'biolink:treats_or_applied_or_studied_to_treat', 'biolink:is_sequence_variant_of', 'biolink:same_as', 'biolink:correlated_with', 'biolink:causes', 'biolink:related_to', 'biolink:has_part', 'biolink:derives_from']}}, 'nodes': {'n00': {'ids': ['MONDO:0018874']}, 'n01': {'categories': ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']}}}}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 17
#      15 print(query_copy)
#      16 ## optimize on our private copy
# ---> 17 query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
#      18 print(query_json_cur)
#      19 response = requests.post(API_url_cur, json=query_json_cur)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.11/site-packages/TCT/translator_query.py:70, in optimize_query_json(query_json, API_name_cur, API_predicates)
#      68 query_json_cur = query_json.copy()  # copy the query_json to avoid modifying the original query_json
#      69 # Get the list of APIs that support the predicates in the query
# ---> 70 shared_predicates = list(set(API_predicates[API_name_cur]).intersection(query_json_cur['message']['query_graph']['edges']['e00']['predicates'] ))
#      72 if len(shared_predicates) > 0:
#      73     query_json_cur['message']['query_graph']['edges']['e00']['predicates'] = shared_predicates
#
# KeyError: 'AMLKG'

# %%
# print(API_predicates)

# %%
## aml kg one
API_name_cur = 'AMLKG'

# API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
print(query_copy)

## break down optimize_query_json()
query_json_cur = query_json.copy()  # copy the query_json to avoid modifying the original query_json
# Get the list of APIs that support the predicates in the query
shared_predicates = list(set(API_predicates[API_name_cur]).intersection(query_json_cur['message']['query_graph']['edges']['e00']['predicates'] ))

print(shared_predicates)
# Out:
# https://amlkg.systemsbiology.org:9990/AMLkg/query
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       7 print(API_url_cur)
#       8 ## deep‐copy so we never touch the caller’s data
# ----> 9 query_copy = deepcopy(query_json)
#      10 print(query_copy)
#      12 ## break down optimize_query_json()
#
# NameError: name 'deepcopy' is not defined

# %% [markdown]
# ## Retrieves the TRAPI meta knowledge graph for 1) the default KP or 2) the specified KP.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/query' -H 'Content-Type: application/json' -d '{"message":{"query_graph":{"edges":{"e00":{"subject":"n00","object":"n01"}},"nodes":{"n00":{"ids":["NCBIGene:216"]},"n01":{}}}}}'

# %% [markdown]
# ## Retrieves edges between specified node pairs.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/get_edges' -H 'Content-Type: application/json' -d '{"pairs":[["NCBIGene:216", "CL:0000037"], ["NCBIGene:100532731", "CL:0000037"]]}'

# %% [markdown]
# ## Retrieves neighbors for the specified nodes, with optional filtering by categories and predicates.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/get_neighbors' -H 'Content-Type: application/json' -d '{"node_ids":["NCBIGene:216"]}'
