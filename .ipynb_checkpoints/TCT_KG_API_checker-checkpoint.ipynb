# %%
## sample curl post
# curl -X 'POST' \
#   'http://multiomics.rtx.ai:8000/rebuild' \
#   -H 'accept: application/json' \
#   -H 'Content-Type: application/json' \
#   -H 'Authorization: Bearer detaillambhardshipbasket' \
#   -d '{
#    "branch": "multiomics"
# }'

# %%
#!pip install TCT

from TCT import node_normalizer
from TCT import name_resolver
from TCT import translator_metakg
from TCT import translator_kpinfo
from TCT import translator_query
from TCT import TCT

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json
import pandas as pd
import numpy as np

# %%
Translator_KP_info, APInames= translator_kpinfo.get_translator_kp_info()
print(len(Translator_KP_info))
# Step 2: Get metaKG and all predicates from Translator APIs through the SmartAPI system
metaKG = translator_metakg.get_KP_metadata(APInames) 
print(metaKG.shape)
# Add metaKG from Plover API based KG resources
APInames,metaKG = translator_metakg.add_plover_API(APInames, metaKG)
print(metaKG.shape)
    # Step 3: list metaKG information
All_predicates = list(set(metaKG['Predicate']))
All_categories = list((set(list(set(metaKG['Subject']))+list(set(metaKG['Object'])))))
API_withMetaKG = list(set(metaKG['API']))

# generate a dictionary of API and its predicates
API_predicates = {}
for api in API_withMetaKG:
    print(api)
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# 53
# (10576, 5)
# (21936, 5)
# BioThings Explorer (BTE) TRAPI
# RTX KG2 - TRAPI 1.5.0
# Clinical Trials KP - TRAPI 1.5.0
# Automat-cam-kp(Trapi v1.5.0)
# Automat-ubergraph(Trapi v1.5.0)
# Automat-drug-central(Trapi v1.5.0)
# Automat-gtopdb(Trapi v1.5.0)
# Automat-gwas-catalog(Trapi v1.5.0)
# Multiomics KP - TRAPI 1.5.0
# SPOKE KP for TRAPI 1.5
# Text Mined Cooccurrence API
# Automat-viral-proteome(Trapi v1.5.0)
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Automat-binding-db(Trapi v1.5.0)
# Drug Approvals KP - TRAPI 1.5.0
# Automat-string-db(Trapi v1.5.0)
# COHD TRAPI
# Automat-icees-kg(Trapi v1.5.0)
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0
# Automat-pharos(Trapi v1.5.0)
# MolePro
# Automat-panther(Trapi v1.5.0)
# Automat-hetionet(Trapi v1.5.0)
# Automat-gtex(Trapi v1.5.0)
# Automat-reactome(Trapi v1.5.0)
# Service Provider TRAPI
# Automat-monarchinitiative(Trapi v1.5.0)
# Knowledge Collaboratory API
# Microbiome KP - TRAPI 1.5.0
# Automat-hmdb(Trapi v1.5.0)
# Automat-human-goa(Trapi v1.5.0)
# imProving Agent for TRAPI 1.5
# Connections Hypothesis Provider API
# Gene-List Network Enrichment Analysis
# Automat-robokop(Trapi v1.5.0)
# Automat-ehr-may-treat-kp(Trapi v1.5.0)
# Automat-hgnc(Trapi v1.5.0)
# Automat-ehr-clinical-connections-kp(Trapi v1.5.0)
# Automat-ctd(Trapi v1.5.0)
# Automat-intact(Trapi v1.5.0)
# Genetics Data Provider for NCATS Biomedical Translator Reasoners
# Automat-genome-alliance(Trapi v1.5.0)

# %%
APInames_sele = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'}
selected_KGs = ['AMLKG']

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

APInames_plover, metaKG_plover = translator_metakg.add_plover_API(APInames_sele, metaKG_sele)

# %%
# print(metaKG_plover[metaKG_plover['API'] == 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0'])

# %%
print(metaKG_plover[metaKG_plover['API'] == 'AMLKG'])
# Out:
# Empty DataFrame
# Columns: [API, Predicate, Subject, Object, URL]
# Index: []

# %%
print(APInames_plover)
# Out:
# {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query', 'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query', 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query', 'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query', 'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query', 'Multiomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/multiomics/query', 'Microbiome KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/mbkp/query', 'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query'}

# %%
## add_plover_API() is hard-coded to existing KPs only!!
## need the general method to manually add the AMLKG kp

url = 'https://amlkg.systemsbiology.org:9990/AMLkg/meta_knowledge_graph'
response = requests.get(url)
data = response.json()
for i in range(len(data["edges"])):
    APInames, metaKG = translator_metakg.add_new_API_for_query(APInames, metaKG, "AMLKG", "https://amlkg.systemsbiology.org:9990/AMLkg/query", data["edges"][i]['predicate'], data["edges"][i]['subject'], data["edges"][i]['object'])

# %%
print(APInames)
# Out:
# {'mediKanren': 'https://medikanren-trapi.transltr.io/query/', 'SPOKE KP for TRAPI 1.5': 'https://spokekp.transltr.io/api/v1.5/query/', 'COHD TRAPI': 'https://cohd-api.transltr.io/api/query/', 'Service Provider TRAPI': 'https://bte.transltr.io/v1/team/Service%20Provider/query/', 'Gene-List Network Enrichment Analysis': 'https://translator.broadinstitute.org/gelinea-trapi/v1.5/query/', 'Connections Hypothesis Provider API': 'https://chp-api.transltr.io/query/', 'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query', 'Microbiome KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/mbkp/query', 'ARAX Translator Reasoner - TRAPI 1.5.0': 'https://arax.transltr.io/api/arax/v1.4/query/', 'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query', 'Automat-ehr-may-treat-kp(Trapi v1.5.0)': 'https://automat.renci.org/ehr-may-treat-kp/query/', 'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query', 'BioThings Explorer (BTE) TRAPI': 'https://bte.transltr.io/v1/query/', 'MolePro': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.5/query/', 'Automat-genome-alliance(Trapi v1.5.0)': 'https://automat.transltr.io/genome-alliance/query/', 'Automat-hgnc(Trapi v1.5.0)': 'https://automat.transltr.io/hgnc/query/', 'Automat-binding-db(Trapi v1.5.0)': 'https://automat.transltr.io/binding-db/query/', 'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query', 'Automat-pharos(Trapi v1.5.0)': 'https://automat.transltr.io/pharos/query/', 'Answer-coalesce(Trapi v1.5.0)': 'https://answer-coalesce.transltr.io/query/', 'imProving Agent for TRAPI 1.5': 'https://ia.transltr.io/api/v1.5/query/', 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query', 'Multiomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/multiomics/query', 'Automat-gtex(Trapi v1.5.0)': 'https://automat.transltr.io/gtex/query/', 'Automat-string-db(Trapi v1.5.0)': 'https://automat.transltr.io/string-db/query/', 'Sri-node-normalizer(Trapi v1.5.0)': 'https://nodenorm.transltr.io/1.5/query/', 'Genetics Data Provider for NCATS Biomedical Translator Reasoners': 'https://genetics-kp.transltr.io/genetics_provider/trapi/v1.5/query/', 'Text Mined Cooccurrence API': 'https://cooccurrence.ci.transltr.io/query/', 'Knowledge Collaboratory API': 'https://collaboratory-api.transltr.io/query/', 'Workflow-runner(Trapi v1.5.0)': 'https://translator-workflow-runner.transltr.io/query/', 'Automat-drug-central(Trapi v1.5.0)': 'https://automat.transltr.io/drugcentral/query/', 'Automat-icees-kg(Trapi v1.5.0)': 'https://automat.transltr.io/icees-kg/query/', 'Automat-cam-kp(Trapi v1.5.0)': 'https://automat.transltr.io/cam-kp/query/', 'Automat-reactome(Trapi v1.5.0)': 'https://automat.transltr.io/reactome/query/', 'Automat-gtopdb(Trapi v1.5.0)': 'https://automat.transltr.io/gtopdb/query/', 'Cqs(Trapi v1.5.0)': 'https://cqs.ci.transltr.io/query/', 'Automat-hmdb(Trapi v1.5.0)': 'https://automat.transltr.io/hmdb/query/', 'Automat-ehr-clinical-connections-kp(Trapi v1.5.0)': 'https://automat.renci.org/ehr-clinical-connections-kp/query/', 'Automat-hetionet(Trapi v1.5.0)': 'https://automat.transltr.io/hetio/query/', 'Automat-intact(Trapi v1.5.0)': 'https://automat.transltr.io/intact/query/', 'Automat-panther(Trapi v1.5.0)': 'https://automat.transltr.io/panther/query/', 'Automat-monarchinitiative(Trapi v1.5.0)': 'https://automat.transltr.io/monarch-kg/query/', 'Automat-robokop(Trapi v1.5.0)': 'https://automat.transltr.io/robokopkg/query/', 'Automat-gwas-catalog(Trapi v1.5.0)': 'https://automat.transltr.io/gwas-catalog/query/', 'Sri-answer-appraiser(Trapi v1.5.0)': 'https://answerappraiser.transltr.io/query/', 'OpenPredict API': 'https://openpredict.transltr.io/query/', 'Autonomous Relay System (ARS) TRAPI': 'https://ars-prod.transltr.io/ars/api/submit/', 'Automat-human-goa(Trapi v1.5.0)': 'https://automat.transltr.io/human-goa/query/' ...

# %%
print(metaKG[metaKG['API'] == 'AMLKG'])
# Out:
#          API                                          Predicate  \
# 21936  AMLKG                               biolink:expressed_in
# 21937  AMLKG                                  biolink:regulates
# 21938  AMLKG                                  biolink:regulates
# 21939  AMLKG                                  biolink:regulates
# 21940  AMLKG                                  biolink:regulates
# 21941  AMLKG                                  biolink:regulates
# 21942  AMLKG                                  biolink:regulates
# 21943  AMLKG                                  biolink:regulates
# 21944  AMLKG                                  biolink:regulates
# 21945  AMLKG                                  biolink:regulates
# 21946  AMLKG                                  biolink:regulates
# 21947  AMLKG                                  biolink:regulates
# 21948  AMLKG                                  biolink:regulates
# 21949  AMLKG                                  biolink:regulates
# 21950  AMLKG                                  biolink:regulates
# 21951  AMLKG                                  biolink:regulates
# 21952  AMLKG                                  biolink:regulates
# 21953  AMLKG                                  biolink:regulates
# 21954  AMLKG                                  biolink:regulates
# 21955  AMLKG                                  biolink:regulates
# 21956  AMLKG                                  biolink:regulates
# 21957  AMLKG                            biolink:in_complex_with
# 21958  AMLKG                            biolink:in_complex_with
# 21959  AMLKG                                  biolink:regulates
# 21960  AMLKG                            biolink:in_complex_with
# 21961  AMLKG                                  biolink:regulates
# 21962  AMLKG                                  biolink:regulates
# 21963  AMLKG                            biolink:in_complex_with
# 21964  AMLKG                                  biolink:regulates
# 21965  AMLKG                                  biolink:regulates
# 21966  AMLKG                                  biolink:regulates
# 21967  AMLKG                                  biolink:regulates
# 21968  AMLKG                            biolink:in_complex_with
# 21969  AMLKG                                  biolink:regulates
# 21970  AMLKG                                  biolink:regulates
# 21971  AMLKG                                  biolink:regulates
# 21972  AMLKG                                  biolink:regulates
# 21973  AMLKG                                  biolink:regulates
# 21974  AMLKG                                  biolink:regulates
# 21975  AMLKG                                  biolink:regulates
# 21976  AMLKG                                  biolink:regulates
# 21977  AMLKG             biolink:associated_with_sensitivity_to
# 21978  AMLKG              biolink:associated_with_resistance_to
# 21979  AMLKG  biolink:GeneToDiseaseOrPhenotypicFeatureAssoci...
# 21980  AMLKG                                     biolink:treats
# 21981  AMLKG                                biolink:subclass_of
#
#                              Subject                         Object  \
# 21936                   biolink:Gene                   biolink:Cell
# 21937                   biolink:Gene                   biolink:Gene
# 21938  biolink:MacromolecularComplex                   biolink:Gene
# 21939  biolink:MacromolecularComplex      biolink:PhenotypicFeature
# 21940         biolink:ChemicalEntity                   biolink:Gene
# 21941                biolink:Protein                   biolink:Gene
# 21942                   biolink:Gene  biolink:MacromolecularComplex
# 21943          biolink:SmallMolecule                   biolink:Gene
# 21944          biolink:SmallMolecule          biolink:SmallMolecule
# 21945          biolink:SmallMolecule          biolink:ProteinFamily
# 21946          biolink:ProteinFamily                   biolink:Gene
# 21947   biolink:EnvironmentalProcess                   biolink:Gene
# 21948                   biolink:Gene      biolink:PhenotypicFeature
# 21949  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 21950                   biolink:Gene                biolink:Protein
# 21951          biolink:ProteinFamily          biolink:ProteinFamily
# 21952          biolink:ProteinFamily  biolink:MacromolecularComplex
# 21953         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 21954          biolink:SmallMolecule  biolink:MacromolecularComplex
# 21955  biolink:MacromolecularComplex                biolink:Protein
# 21956  biolink:MacromolecularComplex          biolink:ProteinFamily
# 21957          biolink:ProteinFamily  biolink:MacromolecularComplex
# 21958  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 21959                biolink:Protein      biolink:PhenotypicFeature
# 21960          biolink:SmallMolecule  biolink:MacromolecularComplex
# 21961         biolink:ChemicalEntity          biolink:ProteinFamily
# 21962               biolink:MicroRNA                   biolink:Gene
# 21963         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 21964          biolink:ProteinFamily      biolink:PhenotypicFeature
# 21965          biolink:SmallMolecule      biolink:PhenotypicFeature
# 21966                   biolink:Drug                   biolink:Gene
# 21967                biolink:Protein  biolink:MacromolecularComplex
# 21968                biolink:Protein  biolink:MacromolecularComplex
# 21969   biolink:Noncoding_RNAProduct                   biolink:Gene
# 21970                biolink:Protein          biolink:ProteinFamily
# 21971         biolink:ChemicalEntity                biolink:Protein
# 21972          biolink:ProteinFamily                biolink:Protein
# 21973   biolink:EnvironmentalProcess          biolink:SmallMolecule
# 21974          biolink:SmallMolecule                biolink:Protein
# 21975               biolink:MicroRNA      biolink:PhenotypicFeature
# 21976               biolink:MicroRNA                biolink:Protein
# 21977                   biolink:Gene                   biolink:Drug
# 21978                   biolink:Gene                   biolink:Drug
# 21979                   biolink:Gene                biolink:Disease
# 21980                   biolink:Drug                biolink:Disease
# 21981                biolink:Disease                biolink:Disease
#
#                                                      URL
# 21936  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21937  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21938  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21939  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21940  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21941  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21942  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21943  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21944  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21945  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21946  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21947  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21948  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21949  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21950  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21951  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21952  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21953  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21954  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21955  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21956  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21957  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21958  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21959  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21960  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21961  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21962  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21963  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21964  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21965  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21966  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21967  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21968  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21969  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21970  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21971  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21972  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21973  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21974  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21975  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21976  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21977  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21978  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21979  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21980  https://amlkg.systemsbiology.org:9990/AMLkg/query
# 21981  https://amlkg.systemsbiology.org:9990/AMLkg/query

# %%
# print(API_predicates)

# %%
import networkx as nx
selected_KGs = ['AMLKG']

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

# build a multigraph to capture all edges (including duplicates) and their predicates
G = nx.MultiGraph()
for _, row in metaKG_sele.iterrows():
        G.add_edge(row['Subject'], row['Object'], predicate=row['Predicate'])

# layout and draw nodes + edges
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, k=0.5, iterations=20)
nx.draw(G, pos,
                with_labels=True,
                node_size=50,
                font_size=12,
                font_color='black',
                node_color='blue',
                edge_color='gray')

# draw edge labels
edge_labels = nx.get_edge_attributes(G, 'predicate')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)
plt.title('Interaction Graph of Subjects and Objects in metaKG')
plt.show()

# %%
# metaKG_sele

# %%
# APInames

# %%
## This is the step missing, generate a dictionary of API and remember to add the new AMLKG one into this dictionary!!

All_predicates = list(set(metaKG['Predicate']))
API_withMetaKG = list(set(metaKG['API']))

# generate a dictionary of API and its predicates
API_predicates = {}
for api in API_withMetaKG:
    print(api)
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# BioThings Explorer (BTE) TRAPI
# RTX KG2 - TRAPI 1.5.0
# AMLKG
# Clinical Trials KP - TRAPI 1.5.0
# Automat-cam-kp(Trapi v1.5.0)
# Automat-ubergraph(Trapi v1.5.0)
# Automat-drug-central(Trapi v1.5.0)
# Automat-gtopdb(Trapi v1.5.0)
# Automat-gwas-catalog(Trapi v1.5.0)
# Multiomics KP - TRAPI 1.5.0
# SPOKE KP for TRAPI 1.5
# Text Mined Cooccurrence API
# Automat-viral-proteome(Trapi v1.5.0)
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Automat-binding-db(Trapi v1.5.0)
# Drug Approvals KP - TRAPI 1.5.0
# Automat-string-db(Trapi v1.5.0)
# COHD TRAPI
# Automat-icees-kg(Trapi v1.5.0)
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0
# Automat-pharos(Trapi v1.5.0)
# MolePro
# Automat-panther(Trapi v1.5.0)
# Automat-hetionet(Trapi v1.5.0)
# Automat-gtex(Trapi v1.5.0)
# Automat-reactome(Trapi v1.5.0)
# Service Provider TRAPI
# Automat-monarchinitiative(Trapi v1.5.0)
# Knowledge Collaboratory API
# Microbiome KP - TRAPI 1.5.0
# Automat-hmdb(Trapi v1.5.0)
# Automat-human-goa(Trapi v1.5.0)
# imProving Agent for TRAPI 1.5
# Connections Hypothesis Provider API
# Gene-List Network Enrichment Analysis
# Automat-robokop(Trapi v1.5.0)
# Automat-ehr-may-treat-kp(Trapi v1.5.0)
# Automat-hgnc(Trapi v1.5.0)
# Automat-ehr-clinical-connections-kp(Trapi v1.5.0)
# Automat-ctd(Trapi v1.5.0)
# Automat-intact(Trapi v1.5.0)
# Genetics Data Provider for NCATS Biomedical Translator Reasoners
# Automat-genome-alliance(Trapi v1.5.0)

# %%
# print(API_predicates)

# %%
## use neiborhood_finder


input_node_id, result, result_parsed, result_ranked_by_primary_infores = TCT.Neiborhood_finder('AML',
                                                                                            node2_categories = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity'],
                                                                                            ## check all APIs
                                                                                            # APInames = APInames,
                                                                                            # metaKG = metaKG,
                                                                                            ## example of checking specific API
                                                                                            #APInames = {'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query'},
                                                                                            # APInames = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'},
                                                                                            # metaKG = metaKG_sele,
                                                                                            APInames = APInames,
                                                                                            metaKG = metaKG,
                                                                                            API_predicates = API_predicates)
# Out:
# MONDO:0018874
# AMLKG: Success!
# 'Automat-ehr-may-treat-kp(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-ehr-clinical-connections-kp(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'COHD TRAPI' generated an exception: argument of type 'NoneType' is not iterable
# 'imProving Agent for TRAPI 1.5' generated an exception: argument of type 'NoneType' is not iterable
# 'SPOKE KP for TRAPI 1.5' generated an exception: argument of type 'NoneType' is not iterable
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'MolePro' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-hmdb(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-ubergraph(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-icees-kg(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# 'Automat-reactome(Trapi v1.5.0)' generated an exception: argument of type 'NoneType' is not iterable
# Automat-hetionet(Trapi v1.5.0): Success!
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Automat-monarchinitiative(Trapi v1.5.0): Success!
# 'Knowledge Collaboratory API' generated an exception: argument of type 'NoneType' is not iterable
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Automat-ctd(Trapi v1.5.0): Success!
# Automat-drug-central(Trapi v1.5.0): Success!
# Automat-robokop(Trapi v1.5.0): Success!
# Text Mined Cooccurrence API: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!
# Service Provider TRAPI: Success!
# BioThings Explorer (BTE) TRAPI: Success!
# NodeNorm does not know about these identifiers: DRUGBANK:DB15060,REACT:R-ALL-9692345,DRUGBANK:DB04945,UNII:FR89SC8CT4,UNII:3D2KVS9K7P,UNII:PVH8394DLN,UNII:3FXW1IW7WT,UNII:RXG7T6RB8K,UNII:E6349B696W,UNII:ET4JC4S66E,UNII:Y8DGL9885E,UNII:475247QF1Z,UNII:O5V0F26RUW,UNII:Q805XO2F7C,UNII:VS12X225PL,UNII:L4D9X59F34,UNII:IZR558KO53,UNII:OEN4982XNW,MESH:D000596,MESH:C081693,MESH:C059764,MESH:D000269,MESH:D000395,MESH:D045930,MESH:C411062,MESH:C039418,MESH:C060154,MESH:C031179,MESH:C052498,MESH:C087490,MESH:D006202,MESH:C084574,MESH:C400142,MESH:C063694,MESH:C014553,MESH:C518484,MESH:C060751,UMLS:DC0003818,UMLS:DC0012155,UMLS:DC0037549,UMLS:DC0041411,UNII:7EV65EAW6H,UMLS:C0596087,UMLS:C0002073,UMLS:C0062128,UMLS:C0597573,MESH:C438312,RXCUI:1791496,RXCUI:1736582,RXCUI:1722942,RXCUI:1433769,RXCUI:1795154,RXCUI:1662281,RXCUI:1362058,RXCUI:1860240,RXCUI:1807509,RXCUI:1665191,RXCUI:1362049,RXCUI:1656667,RXCUI:1362054,RXCUI:1723777,RXCUI:379454,RXCUI:1860464,RXCUI:1658260,RXCUI:1795608,RXCUI:1666799,RXCUI:1729198,RXCUI:1360104,RXCUI:1719287,RXCUI:900963

# %%
# Step 8: Visualize the results
TCT.visulization_one_hop_ranking(result_ranked_by_primary_infores, result_parsed,
                                num_of_nodes = 50, input_query = input_node_id, 
                                fontsize = 5)
# Out:
# NodeNorm does not know about these identifiers: UNII:IZR558KO53,UNII:FR89SC8CT4,UNII:ET4JC4S66E,UNII:Y8DGL9885E,UNII:E6349B696W,UNII:PVH8394DLN,UNII:O5V0F26RUW,UNII:7EV65EAW6H,MESH:C411062,UMLS:DC0003818,UMLS:DC0012155,UNII:475247QF1Z,UNII:OEN4982XNW,UNII:Q805XO2F7C,UNII:VS12X225PL,RXCUI:1791496,RXCUI:1736582,RXCUI:1722942,UNII:L4D9X59F34,RXCUI:1360104,RXCUI:1719287,UNII:3FXW1IW7WT,UNII:RXG7T6RB8K,RXCUI:1807509,RXCUI:1665191,RXCUI:1723777,RXCUI:379454,UNII:3D2KVS9K7P,RXCUI:1362049,RXCUI:1362054,RXCUI:1656667,RXCUI:1860240,RXCUI:1860464,RXCUI:1362058,RXCUI:1662281,RXCUI:1795154,RXCUI:1433769,RXCUI:1658260,RXCUI:1666799,RXCUI:1795608,RXCUI:1729198,UMLS:C0597573,UMLS:C0062128,UMLS:C0596087,MESH:C438312,UMLS:C0002073,MESH:C081693,MESH:C059764,MESH:D000596,MESH:C060751,MESH:C518484,MESH:C014553,MESH:C063694,MESH:C400142,MESH:C084574,MESH:D006202,MESH:C087490,MESH:C052498,MESH:C031179,MESH:C060154,MESH:C039418,MESH:D045930,MESH:D000395,MESH:D000269,UMLS:DC0041411,UMLS:DC0037549,REACT:R-ALL-9692345,DRUGBANK:DB15060,DRUGBANK:DB04945,RXCUI:900963
# [Text(0.5, 0, 'Cytarabine'), Text(2.5, 0, 'Doxorubicin'), Text(4.5, 0, 'Midostaurin'), Text(6.5, 0, 'Quizartinib'), Text(8.5, 0, 'Gilteritinib'), Text(10.5, 0, 'Etoposide'), Text(12.5, 0, 'Venetoclax'), Text(14.5, 0, 'Glasdegib'), Text(16.5, 0, 'Ivosidenib'), Text(18.5, 0, 'Hydroxyurea'), Text(20.5, 0, 'dexamethasone sodium phosphate'), Text(22.5, 0, 'Fludarabine'), Text(24.5, 0, 'Lenalidomide'), Text(26.5, 0, 'Allopurinol'), Text(28.5, 0, 'Bortezomib'), Text(30.5, 0, 'valproate semisodium'), Text(32.5, 0, 'Docetaxel'), Text(34.5, 0, 'Aclarubicin'), Text(36.5, 0, 'Prednisolone'), Text(38.5, 0, 'ruxolitinib phosphate'), Text(40.5, 0, 'imatinib methanesulfonate'), Text(42.5, 0, 'Gemtuzumab'), Text(44.5, 0, 'Busulfan'), Text(46.5, 0, 'Metformin'), Text(48.5, 0, 'Acetaminophen')]
# [Text(0.5, 0, 'Cytarabine'), Text(2.5, 0, 'Doxorubicin'), Text(4.5, 0, 'Midostaurin'), Text(6.5, 0, 'Quizartinib'), Text(8.5, 0, 'Gilteritinib'), Text(10.5, 0, 'Etoposide'), Text(12.5, 0, 'Venetoclax'), Text(14.5, 0, 'Glasdegib'), Text(16.5, 0, 'Ivosidenib'), Text(18.5, 0, 'Hydroxyurea'), Text(20.5, 0, 'dexamethasone sodium phosphate'), Text(22.5, 0, 'Fludarabine'), Text(24.5, 0, 'Lenalidomide'), Text(26.5, 0, 'Allopurinol'), Text(28.5, 0, 'Bortezomib'), Text(30.5, 0, 'valproate semisodium'), Text(32.5, 0, 'Docetaxel'), Text(34.5, 0, 'Aclarubicin'), Text(36.5, 0, 'Prednisolone'), Text(38.5, 0, 'ruxolitinib phosphate'), Text(40.5, 0, 'imatinib methanesulfonate'), Text(42.5, 0, 'Gemtuzumab'), Text(44.5, 0, 'Busulfan'), Text(46.5, 0, 'Metformin'), Text(48.5, 0, 'Acetaminophen')]
#                                                Cytarabine  Azacitidine  \
# biolink:studied_to_treat                                0            1
# biolink:has_adverse_event                               1            1
# biolink:disrupts                                        0            0
# biolink:associated_with                                 0            0
# biolink:affects                                         1            0
# biolink:location_of                                     0            0
# biolink:in_clinical_trials_for                          1            1
# biolink:subclass_of                                     0            0
# biolink:predisposes_to_condition                        0            0
# biolink:applied_to_treat                                1            1
# biolink:treats_or_applied_or_studied_to_treat           1            1
# biolink:positively_correlated_with                      1            1
# biolink:causes                                          1            0
# biolink:treats                                          1            1
# biolink:occurs_together_in_literature_with              1            1
# biolink:contributes_to                                  0            0
# biolink:related_to                                      1            1
# biolink:produced_by                                     0            0
#
#                                                Doxorubicin  Tretinoin  \
# biolink:studied_to_treat                                 0          1
# biolink:has_adverse_event                                1          1
# biolink:disrupts                                         0          0
# biolink:associated_with                                  1          1
# biolink:affects                                          0          1
# biolink:location_of                                      0          0
# biolink:in_clinical_trials_for                           1          1
# biolink:subclass_of                                      0          0
# biolink:predisposes_to_condition                         0          0
# biolink:applied_to_treat                                 1          0
# biolink:treats_or_applied_or_studied_to_treat            1          1
# biolink:positively_correlated_with                       1          1
# biolink:causes                                           1          1
# biolink:treats                                           1          1
# biolink:occurs_together_in_literature_with               1          1
# biolink:contributes_to                                   1          1
# biolink:related_to                                       1          1
# biolink:produced_by                                      0          0
#
#                                                Midostaurin  Decitabine  \
# biolink:studied_to_treat                                 1           1
# biolink:has_adverse_event                                0           1
# biolink:disrupts                                         0           0
# biolink:associated_with                                  0           0
# biolink:affects                                          0           1
# biolink:location_of                                      0           0
# biolink:in_clinical_trials_for                           1           1
# biolink:subclass_of                                      0           0
# biolink:predisposes_to_condition                         0           0
# biolink:applied_to_treat                                 1           1
# biolink:treats_or_applied_or_studied_to_treat            1           1
# biolink:positively_correlated_with                       0           1
# biolink:causes                                           0           0
# biolink:treats                                           1           1
# biolink:occurs_together_in_literature_with               1           0
# biolink:contributes_to                                   0           0
# biolink:related_to                                       1           1
# biolink:produced_by                                      0           0
#
#                                                Quizartinib  \
# biolink:studied_to_treat                                 1
# biolink:has_adverse_event                                0
# biolink:disrupts                                         0
# biolink:associated_with                                  0
# biolink:affects                                          0
# biolink:location_of                                      0
# biolink:in_clinical_trials_for                           1
# biolink:subclass_of                                      0
# biolink:predisposes_to_condition                         0
# biolink:applied_to_treat                                 1
# biolink:treats_or_applied_or_studied_to_treat            1
# biolink:positively_correlated_with                       0
# biolink:causes                                           0
# biolink:treats                                           1
# biolink:occurs_together_in_literature_with               1
# biolink:contributes_to                                   0
# biolink:related_to                                       1
# biolink:produced_by                                      0
#
#                                                Daunorubicin hydrochloride  \
# biolink:studied_to_treat                                                0
# biolink:has_adverse_event                                               1
# biolink:disrupts                                                        0
# biolink:associated_with                                                 0
# biolink:affects                                                         1
# biolink:location_of                                                     0
# biolink:in_clinical_trials_for                                          1
# biolink:subclass_of                                                     0
# biolink:predisposes_to_condition                                        0
# biolink:applied_to_treat                                                1
# biolink:treats_or_applied_or_studied_to_treat                           1
# biolink:positively_correlated_with                                      1
# biolink:causes                                                          1
# biolink:treats                                                          1
# biolink:occurs_together_in_literature_with                              0
# biolink:contributes_to                                                  0
# biolink:related_to                                                      1
# biolink:produced_by                                                     0
#
#                                                Gilteritinib  Methotrexate  \
# biolink:studied_to_treat                                  1             0
# biolink:has_adverse_event                                 1             1
# biolink:disrupts                                          0             0
# biolink:associated_with                                   0             1
# biolink:affects                                           0             0
# biolink:location_of                                       0             0
# biolink:in_clinical_trials_for                            1             1
# biolink:subclass_of                                       0             0
# biolink:predisposes_to_condition                          0             0
# biolink:applied_to_treat                                  1             1
# biolink:treats_or_applied_or_studied_to_treat             1             1
# biolink:positively_correlated_with                        0             1
# biolink:causes                                            0             0
# biolink:treats                                            1             0
# biolink:occurs_together_in_literature_with                0             0
# biolink:contributes_to                                    0             1
# biolink:related_to                                        1             1
# biolink:produced_by                                       0             0
#
#                                                ...  Atazanavir  Desmopressin  \
# biolink:studied_to_treat                       ...           0             0
# biolink:has_adverse_event                      ...           0             0
# biolink:disrupts                               ...           0             0
# biolink:associated_with                        ...           0             0
# biolink:affects                                ...           0             0
# biolink:location_of                            ...           0             0
# biolink:in_clinical_trials_for                 ...           0             0
# biolink:subclass_of                            ...           0             0
# biolink:predisposes_to_condition               ...           0             0
# biolink:applied_to_treat                       ...           0             0
# biolink:treats_or_applied_or_studied_to_treat  ...           0             0
# biolink:positively_correlated_with             ...           0             0
# biolink:causes                                 ...           0             0
# biolink:treats                                 ...           0             0
# biolink:occurs_together_in_literature_with     ...           1             1
# biolink:contributes_to                         ...           0             0
# biolink:related_to                             ...           0             0
# biolink:produced_by                            ...           0             0
#
#                                                Dihydroergotamine  Prednisone  \
# biolink:studied_to_treat                                       0           0
# biolink:has_adverse_event                                      0           0
# biolink:disrupts                                               0           0
# biolink:associated_with                                        0           0
# biolink:affects                                                0           0
# biolink:location_of                                            0           0
# biolink:in_clinical_trials_for                                 0           0
# biolink:subclass_of                                            0           0
# biolink:predisposes_to_condition                               0           0
# biolink:applied_to_treat                                       0           0
# biolink:treats_or_applied_or_studied_to_treat                  0           0
# biolink:positively_correlated_with                             0           0
# biolink:causes                                                 0           0
# biolink:treats                                                 0           0
# biolink:occurs_together_in_literature_with                     1           1
# biolink:contributes_to                                         0           0
# biolink:related_to                                             0           0
# biolink:produced_by                                            0           0
#
#                                                Procarbazine  Halcinonide  \
# biolink:studied_to_treat                                  0            0
# biolink:has_adverse_event                                 0            0
# biolink:disrupts                                          0            0
# biolink:associated_with                                   0            0
# biolink:affects                                           0            0
# biolink:location_of                                       0            0
# biolink:in_clinical_trials_for                            0            0
# biolink:subclass_of                                       0            0
# biolink:predisposes_to_condition                          0            0
# biolink:applied_to_treat                                  0            0
# biolink:treats_or_applied_or_studied_to_treat             0            0
# biolink:positively_correlated_with                        0            0
# biolink:causes                                            0            0
# biolink:treats                                            0            0
# biolink:occurs_together_in_literature_with                1            1
# biolink:contributes_to                                    0            0
# biolink:related_to                                        0            0
# biolink:produced_by                                       0            0
#
#                                                Salicylic acid  \
# biolink:studied_to_treat                                    0
# biolink:has_adverse_event                                   0
# biolink:disrupts                                            0
# biolink:associated_with                                     0
# biolink:affects                                             0
# biolink:location_of                                         0
# biolink:in_clinical_trials_for                              0
# biolink:subclass_of                                         0
# biolink:predisposes_to_condition                            0
# biolink:applied_to_treat                                    0
# biolink:treats_or_applied_or_studied_to_treat               0
# biolink:positively_correlated_with                          0
# biolink:causes                                              0
# biolink:treats                                              0
# biolink:occurs_together_in_literature_with                  1
# biolink:contributes_to                                      0
# biolink:related_to                                          0
# biolink:produced_by                                         0
#
#                                                4,7-Dimethyl-[1,10]Phenanthroline  \
# biolink:studied_to_treat                                                       0
# biolink:has_adverse_event                                                      0
# biolink:disrupts                                                               0
# biolink:associated_with                                                        0
# biolink:affects                                                                0
# biolink:location_of                                                            0
# biolink:in_clinical_trials_for                                                 0
# biolink:subclass_of                                                            0
# biolink:predisposes_to_condition                                               0
# biolink:applied_to_treat                                                       0
# biolink:treats_or_applied_or_studied_to_treat                                  0
# biolink:positively_correlated_with                                             0
# biolink:causes                                                                 0
# biolink:treats                                                                 0
# biolink:occurs_together_in_literature_with                                     1
# biolink:contributes_to                                                         0
# biolink:related_to                                                             0
# biolink:produced_by                                                            0
#
#                                                Proline  RXCUI:900963
# biolink:studied_to_treat                             0             0
# biolink:has_adverse_event                            0             0
# biolink:disrupts                                     0             0
# biolink:associated_with                              0             0
# biolink:affects                                      0             0
# biolink:location_of                                  0             0
# biolink:in_clinical_trials_for                       0             0
# biolink:subclass_of                                  0             0
# biolink:predisposes_to_condition                     0             0
# biolink:applied_to_treat                             0             0
# biolink:treats_or_applied_or_studied_to_treat        0             0
# biolink:positively_correlated_with                   0             1
# biolink:causes                                       0             0
# biolink:treats                                       0             0
# biolink:occurs_together_in_literature_with           1             0
# biolink:contributes_to                               0             0
# biolink:related_to                                   0             0
# biolink:produced_by                                  0             0
#
# [18 rows x 3918 columns]

# %%
## use neiborhood_finder


input_node_id_amlkg, result_amlkg, result_parsed_amlkg, result_ranked_by_primary_infores_amlkg = TCT.Neiborhood_finder('AML',
                                                                                            node2_categories = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity'],
                                                                                            ## check all APIs
                                                                                            # APInames = APInames,
                                                                                            # metaKG = metaKG,
                                                                                            ## example of checking specific API
                                                                                            #APInames = {'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query'},
                                                                                            # APInames = {'AMLKG': 'https://amlkg.systemsbiology.org:9990/AMLkg/query'},
                                                                                            # metaKG = metaKG_sele,
                                                                                            APInames = APInames,
                                                                                            metaKG = metaKG[metaKG['API'] == 'AMLKG'],
                                                                                            API_predicates = API_predicates)
# Out:
# MONDO:0018874
# AMLKG: Success!

# %% [markdown]
# ### Following are step by step breakdown codes to understand the execption issue
# *

# %%
## test step by step of the TCT.Neiborhood_finder to see which step is failling

from TCT import name_resolver
from TCT import translator_metakg
from TCT import translator_kpinfo
from TCT import translator_query

from TCT import node_normalizer
from TCT import TCT

input_node = 'AML'
input_node_category = ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']
APInames = APInames_plover
metaKG = metaKG_plover
API_predicates = API_predicates

# Step 1: Resolve the input node to get its curie id and categories
input_node_info = name_resolver.lookup(input_node)
input_node_id = input_node_info.curie
print(input_node_id)
    
if len(input_node_category) == 0:
    input_node_category = input_node_info.types 
else:
    input_node_category = list(set(input_node_category).intersection(set(input_node_info.types)))
    if len(input_node_category) == 0:
        input_node_category = input_node_info.types
# Out:
# MONDO:0018874

# %%
## one issue need to load this API function
from TCT import sele_predicates_API

# Step 2: Select predicates and APIs based on the intermediate categories
sele_predicates, sele_APIs, API_URLs = sele_predicates_API(input_node_category,
                                                            node2_categories,
                                                            metaKG, APInames)

# %%
API_URLs
# Out:
# ['https://multiomics.rtx.ai:9990/mbkp/query',
#  'https://multiomics.rtx.ai:9990/multiomics/query',
#  'https://kg2cploverdb.ci.transltr.io/kg2c/query',
#  'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query',
#  'https://multiomics.rtx.ai:9990/ctkp/query',
#  'https://amlkg.systemsbiology.org:9990/AMLkg/query',
#  'https://multiomics.rtx.ai:9990/dakp/query']

# %%
from TCT import format_query_json
# Step 3: Format the query JSON for the input node
query_json = format_query_json([input_node_id], [], 
                                [input_node_category], 
                                node2_categories, 
                                sele_predicates)

# %%
query_json
# Out:
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01',
#      'object': 'n00',
#      'predicates': ['biolink:contributes_to',
#       'biolink:produces',
#       'biolink:has_side_effect',
#       'biolink:coexists_with',
#       'biolink:exacerbates_condition',
#       'biolink:preventative_for_condition',
#       'biolink:chemically_similar_to',
#       'biolink:drug_regulatory_status_world_wide',
#       'biolink:applied_to_treat',
#       'biolink:precedes',
#       'biolink:disrupts',
#       'biolink:physically_interacts_with',
#       'biolink:gene_associated_with_condition',
#       'biolink:associated_with',
#       'biolink:contraindicated_in',
#       'biolink:interacts_with',
#       'biolink:manifestation_of',
#       'biolink:affects',
#       'biolink:predisposes_to_condition',
#       'biolink:treats',
#       'biolink:close_match',
#       'biolink:biomarker_for',
#       'biolink:actively_involved_in',
#       'biolink:composed_primarily_of',
#       'biolink:has_member',
#       'biolink:has_output',
#       'biolink:exact_match',
#       'biolink:in_clinical_trials_for',
#       'biolink:subclass_of',
#       'biolink:located_in',
#       'biolink:has_input',
#       'biolink:has_participant',
#       'biolink:occurs_in',
#       'biolink:treats_or_applied_or_studied_to_treat',
#       'biolink:is_sequence_variant_of',
#       'biolink:same_as',
#       'biolink:correlated_with',
#       'biolink:causes',
#       'biolink:related_to',
#       'biolink:has_part',
#       'biolink:derives_from']}},
#    'nodes': {'n00': {'ids': ['MONDO:0018874']},
#     'n01': {'categories': ['biolink:SmallMolecule',
#       'biolink:Drug',
#       'biolink:ChemicalEntity']}}}}}

# %%
from TCT import translator_query
from TCT import parse_KG
# Step 4: Query the APIs in parallel
result = translator_query.parallel_api_query(query_json=query_json, 
                            select_APIs= sele_APIs, 
                            APInames=APInames,
                            API_predicates=API_predicates,
                            max_workers=len(sele_APIs))
result_parsed = parse_KG(result)
# Out:
# 'AMLKG' generated an exception: 'AMLKG'
# 'Multiomics KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# 'Microbiome KP - TRAPI 1.5.0' generated an exception: argument of type 'NoneType' is not iterable
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!

# %%
## ok, step 4 get the exception, now break down step 4 parallel_api_query function to further id the issue
# Parallel query
result = []
from concurrent.futures import ThreadPoolExecutor, as_completed
from copy import deepcopy
from TCT.translator_query import query_KP

query_json=query_json
select_APIs= sele_APIs
APInames=APInames
API_predicates=API_predicates
max_workers=len(sele_APIs)

with ThreadPoolExecutor(max_workers=max_workers) as executor:

    # copy the query_json for each API to avoid modifying the original query_json
    query_json_cur = deepcopy(query_json)
    # print(query_json_cur)

    for API_name_cur in select_APIs:
         print(API_name_cur)
    
    future_to_url = {executor.submit(query_KP, API_name_cur, query_json_cur, APInames, API_predicates): API_name_cur for API_name_cur in select_APIs}

    # for future in as_completed(future_to_url):
    #     url = future_to_url[future]
    #     try:
    #         data = future.result()
    #         if 'knowledge_graph' in data:
    #             result.append(data)
    #     except Exception as exc:
    #         print('%r generated an exception: %s' % (url, exc))
# Out:
# Microbiome KP - TRAPI 1.5.0
# Multiomics KP - TRAPI 1.5.0
# RTX KG2 - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0
# Clinical Trials KP - TRAPI 1.5.0
# AMLKG
# Drug Approvals KP - TRAPI 1.5.0
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!

# %%
## Now the issue found, it isn't even execute for amlkg
## now break down the query_kp()
from TCT.translator_query import optimize_query_json

## working one
API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

## aml kg one
# API_name_cur = 'AMLKG'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
# print(query_copy)
## optimize on our private copy
query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
print(query_json_cur)
response = requests.post(API_url_cur, json=query_json_cur)
print(response)
# Out:
# https://multiomics.rtx.ai:9990/dakp/query
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01', 'object': 'n00', 'predicates': ['biolink:applied_to_treat', 'biolink:treats']}}, 'nodes': {'n00': {'ids': ['MONDO:0018874']}, 'n01': {'categories': ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']}}}}}
# <Response [200]>

# %%
## Now the issue found, it isn't even execute for amlkg
## now break down the query_kp()
from TCT.translator_query import optimize_query_json

## working one
# API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

## aml kg one
API_name_cur = 'AMLKG'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
print(query_copy)
## optimize on our private copy
query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
print(query_json_cur)
response = requests.post(API_url_cur, json=query_json_cur)
print(response)
# Out:
# https://amlkg.systemsbiology.org:9990/AMLkg/query
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01', 'object': 'n00', 'predicates': ['biolink:contributes_to', 'biolink:produces', 'biolink:has_side_effect', 'biolink:coexists_with', 'biolink:exacerbates_condition', 'biolink:preventative_for_condition', 'biolink:chemically_similar_to', 'biolink:drug_regulatory_status_world_wide', 'biolink:applied_to_treat', 'biolink:precedes', 'biolink:disrupts', 'biolink:physically_interacts_with', 'biolink:gene_associated_with_condition', 'biolink:associated_with', 'biolink:contraindicated_in', 'biolink:interacts_with', 'biolink:manifestation_of', 'biolink:affects', 'biolink:predisposes_to_condition', 'biolink:treats', 'biolink:close_match', 'biolink:biomarker_for', 'biolink:actively_involved_in', 'biolink:composed_primarily_of', 'biolink:has_member', 'biolink:has_output', 'biolink:exact_match', 'biolink:in_clinical_trials_for', 'biolink:subclass_of', 'biolink:located_in', 'biolink:has_input', 'biolink:has_participant', 'biolink:occurs_in', 'biolink:treats_or_applied_or_studied_to_treat', 'biolink:is_sequence_variant_of', 'biolink:same_as', 'biolink:correlated_with', 'biolink:causes', 'biolink:related_to', 'biolink:has_part', 'biolink:derives_from']}}, 'nodes': {'n00': {'ids': ['MONDO:0018874']}, 'n01': {'categories': ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']}}}}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 17
#      15 print(query_copy)
#      16 ## optimize on our private copy
# ---> 17 query_json_cur = optimize_query_json(query_copy, API_name_cur, API_predicates)
#      18 print(query_json_cur)
#      19 response = requests.post(API_url_cur, json=query_json_cur)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.11/site-packages/TCT/translator_query.py:70, in optimize_query_json(query_json, API_name_cur, API_predicates)
#      68 query_json_cur = query_json.copy()  # copy the query_json to avoid modifying the original query_json
#      69 # Get the list of APIs that support the predicates in the query
# ---> 70 shared_predicates = list(set(API_predicates[API_name_cur]).intersection(query_json_cur['message']['query_graph']['edges']['e00']['predicates'] ))
#      72 if len(shared_predicates) > 0:
#      73     query_json_cur['message']['query_graph']['edges']['e00']['predicates'] = shared_predicates
#
# KeyError: 'AMLKG'

# %%
print(API_predicates)
# Out:
# {'Automat-hmdb(Trapi v1.5.0)': ['biolink:subclass_of', 'biolink:affects', 'biolink:correlated_with', 'biolink:has_participant'], 'Automat-viral-proteome(Trapi v1.5.0)': ['biolink:acts_upstream_of', 'biolink:active_in', 'biolink:subclass_of', 'biolink:has_part', 'biolink:located_in', 'biolink:colocalizes_with', 'biolink:actively_involved_in', 'biolink:catalyzes'], 'Automat-ubergraph(Trapi v1.5.0)': ['biolink:produces', 'biolink:overlaps', 'biolink:derives_into', 'biolink:coexists_with', 'biolink:acts_upstream_of', 'biolink:disrupts', 'biolink:precedes', 'biolink:gene_associated_with_condition', 'biolink:associated_with', 'biolink:homologous_to', 'biolink:affects', 'biolink:has_phenotype', 'biolink:preceded_by', 'biolink:directly_physically_interacts_with', 'biolink:regulates', 'biolink:actively_involved_in', 'biolink:composed_primarily_of', 'biolink:temporally_related_to', 'biolink:has_output', 'biolink:subclass_of', 'biolink:located_in', 'biolink:has_input', 'biolink:develops_from', 'biolink:has_participant', 'biolink:occurs_in', 'biolink:in_taxon', 'biolink:expressed_in', 'biolink:causes', 'biolink:capable_of', 'biolink:related_to', 'biolink:derives_from', 'biolink:has_part', 'biolink:contributes_to'], 'Automat-cam-kp(Trapi v1.5.0)': ['biolink:overlaps', 'biolink:coexists_with', 'biolink:colocalizes_with', 'biolink:precedes', 'biolink:interacts_with', 'biolink:affects', 'biolink:has_phenotype', 'biolink:preceded_by', 'biolink:directly_physically_interacts_with', 'biolink:regulates', 'biolink:acts_upstream_of_negative_effect', 'biolink:actively_involved_in', 'biolink:temporally_related_to', 'biolink:acts_upstream_of_or_within', 'biolink:has_output', 'biolink:enabled_by', 'biolink:active_in', 'biolink:located_in', 'biolink:has_input', 'biolink:acts_upstream_of_or_within_positive_effect', 'biolink:has_participant', 'biolink:occurs_in', 'biolink:enables', 'biolink:acts_upstream_of_positive_effect', 'biolink:causes', 'biolink:capable_of', 'biolink:has_part', 'biolink:acts_upstream_of_or_within_negative_effect'], 'Gene-List Network Enrichment Analysis': ['biolink:enriched_in'], 'BioThings Explorer (BTE) TRAPI': ['biolink:has_sequence_variant', 'biolink:produces', 'biolink:associated_with_resistance_to', 'biolink:has_gene_product', 'biolink:occurs_together_in_literature_with', 'biolink:derives_into', 'biolink:has_manifestation', 'biolink:part_of', 'biolink:coexists_with', 'biolink:exacerbates_condition', 'biolink:adverse_event_of', 'biolink:preventative_for_condition', 'biolink:condition_exacerbated_by', 'biolink:condition_prevented_by', 'biolink:caused_by', 'biolink:actively_involves', 'biolink:food_component_of', 'biolink:is_diagnosed_by', 'biolink:disrupts', 'biolink:precedes', 'biolink:physically_interacts_with', 'biolink:tested_by_preclinical_trials_of', 'biolink:gene_associated_with_condition', 'biolink:associated_with', 'biolink:treatment_applications_from', 'biolink:interacts_with', 'biolink:negatively_associated_with', 'biolink:manifestation_of', 'biolink:contraindicated_in', 'biolink:phenotype_of', 'biolink:superclass_of', 'biolink:affects', 'biolink:contribution_from', 'biolink:increases_response_to', 'biolink:predisposes_to_condition', 'biolink:treats', 'biolink:diagnoses', 'biolink:preceded_by', 'biolink:directly_physically_interacts_with', 'biolink:is_input_of', 'biolink:subject_of_treatment_application_or_study_for_treatment_by', 'biolink:condition_predisposed_by', 'biolink:close_match', 'biolink:associated_with_increased_likelihood_of', 'biolink:actively_involved_in', 'biolink:disrupted_by', 'biolink:catalyzes', 'biolink:has_contraindication', 'biolink:positively_associated_with', 'biolink:treated_by', 'biolink:has_active_component', 'biolink:in_clinical_trials_for', 'biolink:located_in', 'biolink:has_input', 'biolink:negatively_correlated_with', 'biolink:condition_associated_with_gene', 'biolink:contains_process', 'biolink:location_of', 'biolink:associated_with_sensitivity_to', 'biolink:positively_correlated_with',  ...

# %%
## aml kg one
API_name_cur = 'AMLKG'

# API_name_cur = 'Drug Approvals KP - TRAPI 1.5.0'

API_url_cur = APInames[API_name_cur]
print(API_url_cur)
## deep‐copy so we never touch the caller’s data
query_copy = deepcopy(query_json)
print(query_copy)

## break down optimize_query_json()
query_json_cur = query_json.copy()  # copy the query_json to avoid modifying the original query_json
# Get the list of APIs that support the predicates in the query
shared_predicates = list(set(API_predicates[API_name_cur]).intersection(query_json_cur['message']['query_graph']['edges']['e00']['predicates'] ))

print(shared_predicates)
# Out:
# https://amlkg.systemsbiology.org:9990/AMLkg/query
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n01', 'object': 'n00', 'predicates': ['biolink:contributes_to', 'biolink:produces', 'biolink:has_side_effect', 'biolink:coexists_with', 'biolink:exacerbates_condition', 'biolink:preventative_for_condition', 'biolink:chemically_similar_to', 'biolink:drug_regulatory_status_world_wide', 'biolink:applied_to_treat', 'biolink:precedes', 'biolink:disrupts', 'biolink:physically_interacts_with', 'biolink:gene_associated_with_condition', 'biolink:associated_with', 'biolink:contraindicated_in', 'biolink:interacts_with', 'biolink:manifestation_of', 'biolink:affects', 'biolink:predisposes_to_condition', 'biolink:treats', 'biolink:close_match', 'biolink:biomarker_for', 'biolink:actively_involved_in', 'biolink:composed_primarily_of', 'biolink:has_member', 'biolink:has_output', 'biolink:exact_match', 'biolink:in_clinical_trials_for', 'biolink:subclass_of', 'biolink:located_in', 'biolink:has_input', 'biolink:has_participant', 'biolink:occurs_in', 'biolink:treats_or_applied_or_studied_to_treat', 'biolink:is_sequence_variant_of', 'biolink:same_as', 'biolink:correlated_with', 'biolink:causes', 'biolink:related_to', 'biolink:has_part', 'biolink:derives_from']}}, 'nodes': {'n00': {'ids': ['MONDO:0018874']}, 'n01': {'categories': ['biolink:SmallMolecule', 'biolink:Drug', 'biolink:ChemicalEntity']}}}}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 15
#      13 query_json_cur = query_json.copy()  # copy the query_json to avoid modifying the original query_json
#      14 # Get the list of APIs that support the predicates in the query
# ---> 15 shared_predicates = list(set(API_predicates[API_name_cur]).intersection(query_json_cur['message']['query_graph']['edges']['e00']['predicates'] ))
#      17 print(shared_predicates)
#
# KeyError: 'AMLKG'

# %% [markdown]
# ## Retrieves the TRAPI meta knowledge graph for 1) the default KP or 2) the specified KP.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/query' -H 'Content-Type: application/json' -d '{"message":{"query_graph":{"edges":{"e00":{"subject":"n00","object":"n01"}},"nodes":{"n00":{"ids":["NCBIGene:216"]},"n01":{}}}}}'

# %% [markdown]
# ## Retrieves edges between specified node pairs.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/get_edges' -H 'Content-Type: application/json' -d '{"pairs":[["NCBIGene:216", "CL:0000037"], ["NCBIGene:100532731", "CL:0000037"]]}'

# %% [markdown]
# ## Retrieves neighbors for the specified nodes, with optional filtering by categories and predicates.

# %%
# curl -X 'POST' 'https://amlkg.systemsbiology.org:9990/get_neighbors' -H 'Content-Type: application/json' -d '{"node_ids":["NCBIGene:216"]}'
